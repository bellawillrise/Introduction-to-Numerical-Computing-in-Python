# %% [markdown]
# # Import packages

# %%
import numpy as np
import pandas as pd
import matplotlib as plt

# %% [markdown]
# `pd.read_csv` - Read csv data with pandas into dataframe.
# pandas `read_xxx` functions infer `datatypes, headers, dates, etc`.
# without explicit declarations or required interventions from user

# %%
data = pd.read_csv("data/movie_metadata.csv")

# %% [markdown]
# To view the first 3 rows:

# %%
data.head(3)
# Out:
#                                  movie_title  color   director_name  \
# 0                                    Avatar   Color   James Cameron
# 1  Pirates of the Caribbean: At World's End   Color  Gore Verbinski
# 2                                   Spectre   Color      Sam Mendes
#
#    num_critic_for_reviews  duration  director_facebook_likes  \
# 0                   723.0     178.0                      0.0
# 1                   302.0     169.0                    563.0
# 2                   602.0     148.0                      0.0
#
#    actor_3_facebook_likes      actor_2_name  actor_1_facebook_likes  \
# 0                   855.0  Joel David Moore                  1000.0
# 1                  1000.0     Orlando Bloom                 40000.0
# 2                   161.0      Rory Kinnear                 11000.0
#
#          gross  ... num_user_for_reviews language  country  content_rating  \
# 0  760505847.0  ...               3054.0  English      USA           PG-13
# 1  309404152.0  ...               1238.0  English      USA           PG-13
# 2  200074175.0  ...                994.0  English       UK           PG-13
#
#         budget  title_year actor_2_facebook_likes imdb_score  aspect_ratio  \
# 0  237000000.0      2009.0                  936.0        7.9          1.78
# 1  300000000.0      2007.0                 5000.0        7.1          2.35
# 2  245000000.0      2015.0                  393.0        6.8          2.35
#
#   movie_facebook_likes
# 0              33000.0
# 1                  0.0
# 2              85000.0
#
# [3 rows x 28 columns]

# %% [markdown]
# To view the last 3 rows:

# %%
data.tail(3)
# Out:
#               movie_title  color   director_name  num_critic_for_reviews  \
# 5041    Shanghai Calling   Color     Daniel Hsia                    14.0
# 5042   My Date with Drew   Color        Jon Gunn                    43.0
# 5043  Starting Over Again    NaN  Olivia Lamasan                     NaN
#
#       duration  director_facebook_likes  actor_3_facebook_likes  \
# 5041     100.0                      0.0                   489.0
# 5042      90.0                     16.0                    16.0
# 5043       NaN                      NaN                     NaN
#
#           actor_2_name  actor_1_facebook_likes    gross  ...  \
# 5041     Daniel Henney                   946.0  10443.0  ...
# 5042  Brian Herzlinger                    86.0  85222.0  ...
# 5043      Toni Gonzaga                     NaN      NaN  ...
#
#      num_user_for_reviews language      country  content_rating  budget  \
# 5041                  9.0  English          USA           PG-13     NaN
# 5042                 84.0  English          USA              PG  1100.0
# 5043                  NaN      NaN  Philippines              PG     NaN
#
#       title_year actor_2_facebook_likes imdb_score  aspect_ratio  \
# 5041      2012.0                  719.0        6.3          2.35
# 5042      2004.0                   23.0        6.6          1.85
# 5043      2014.0                    NaN        NaN           NaN
#
#      movie_facebook_likes
# 5041                660.0
# 5042                456.0
# 5043                  NaN
#
# [3 rows x 28 columns]

# %% [markdown]
# To view the number of samples and features, aka the shape of the dataset:

# %%
#shape = (rows, columns)
data.shape
# Out:
# (5044, 28)

# %% [markdown]
# To get the column names/ feature attributes of the dataframe:

# %%
list(data.columns)
# Out:
# ['movie_title',
#  'color',
#  'director_name',
#  'num_critic_for_reviews',
#  'duration',
#  'director_facebook_likes',
#  'actor_3_facebook_likes',
#  'actor_2_name',
#  'actor_1_facebook_likes',
#  'gross',
#  'genres',
#  'actor_1_name',
#  'num_voted_users',
#  'cast_total_facebook_likes',
#  'actor_3_name',
#  'facenumber_in_poster',
#  'plot_keywords',
#  'movie_imdb_link',
#  'num_user_for_reviews',
#  'language',
#  'country',
#  'content_rating',
#  'budget',
#  'title_year',
#  'actor_2_facebook_likes',
#  'imdb_score',
#  'aspect_ratio',
#  'movie_facebook_likes']

# %% [markdown]
# # Indexing Columns

# %% [markdown]
# To get the values of one column by name:

# %%
data['movie_title']
# Out:
# 0                                                 Avatar
# 1               Pirates of the Caribbean: At World's End
# 2                                                Spectre
# 3                                  The Dark Knight Rises
# 4       Star Wars: Episode VII - The Force Awakens    ...
#                               ...
# 5039                           The Following
# 5040                                A Plague So Pleasant
# 5041                                    Shanghai Calling
# 5042                                   My Date with Drew
# 5043                                  Starting Over Again
# Name: movie_title, Length: 5044, dtype: object

# %% [markdown]
# To get the values of several columns by name:

# %%
data[['movie_title', 'genres']]
# Out:
#                                             movie_title  \
# 0                                               Avatar
# 1             Pirates of the Caribbean: At World's End
# 2                                              Spectre
# 3                                The Dark Knight Rises
# 4     Star Wars: Episode VII - The Force Awakens    ...
# ...                                                 ...
# 5039                         The Following
# 5040                              A Plague So Pleasant
# 5041                                  Shanghai Calling
# 5042                                 My Date with Drew
# 5043                                Starting Over Again
#
#                                genres
# 0     Action|Adventure|Fantasy|Sci-Fi
# 1            Action|Adventure|Fantasy
# 2           Action|Adventure|Thriller
# 3                     Action|Thriller
# 4                         Documentary
# ...                               ...
# 5039     Crime|Drama|Mystery|Thriller
# 5040            Drama|Horror|Thriller
# 5041             Comedy|Drama|Romance
# 5042                      Documentary
# 5043          Romance|Comedy|Filipino
#
# [5044 rows x 2 columns]

# %% [markdown]
# You can also just retrieve a portion of a column.  For instance, we want to get the first 4 director names.
#
# The lower bound is ommitted so it is assumed it assumes the beginning of the list.

# %%
data.director_name[:4]
# Out:
# 0        James Cameron
# 1       Gore Verbinski
# 2           Sam Mendes
# 3    Christopher Nolan
# Name: director_name, dtype: object

# %% [markdown]
# # Indexing Rows

# %% [markdown]
# Retrieving only columns 10-11.
#
# Note: Mathematically, the range is evaluated as `[lower: upper)` which means that the `lower` bound is included while the `upper` is excluded.

# %%
data.iloc[10:12]
# Out:
#                             movie_title  color director_name  \
# 10  Batman v Superman: Dawn of Justice   Color   Zack Snyder
# 11                    Superman Returns   Color  Bryan Singer
#
#     num_critic_for_reviews  duration  director_facebook_likes  \
# 10                   673.0     183.0                      0.0
# 11                   434.0     169.0                      0.0
#
#     actor_3_facebook_likes   actor_2_name  actor_1_facebook_likes  \
# 10                  2000.0   Lauren Cohan                 15000.0
# 11                   903.0  Marlon Brando                 18000.0
#
#           gross  ... num_user_for_reviews language  country  content_rating  \
# 10  330249062.0  ...               3018.0  English      USA           PG-13
# 11  200069408.0  ...               2367.0  English      USA           PG-13
#
#          budget  title_year actor_2_facebook_likes imdb_score  aspect_ratio  \
# 10  250000000.0      2016.0                 4000.0        6.9          2.35
# 11  209000000.0      2006.0                10000.0        6.1          2.35
#
#    movie_facebook_likes
# 10             197000.0
# 11                  0.0
#
# [2 rows x 28 columns]

# %% [markdown]
# To retrieve the first 3 rows:

# %%
data.iloc[:3]
# Out:
#                                  movie_title  color   director_name  \
# 0                                    Avatar   Color   James Cameron
# 1  Pirates of the Caribbean: At World's End   Color  Gore Verbinski
# 2                                   Spectre   Color      Sam Mendes
#
#    num_critic_for_reviews  duration  director_facebook_likes  \
# 0                   723.0     178.0                      0.0
# 1                   302.0     169.0                    563.0
# 2                   602.0     148.0                      0.0
#
#    actor_3_facebook_likes      actor_2_name  actor_1_facebook_likes  \
# 0                   855.0  Joel David Moore                  1000.0
# 1                  1000.0     Orlando Bloom                 40000.0
# 2                   161.0      Rory Kinnear                 11000.0
#
#          gross  ... num_user_for_reviews language  country  content_rating  \
# 0  760505847.0  ...               3054.0  English      USA           PG-13
# 1  309404152.0  ...               1238.0  English      USA           PG-13
# 2  200074175.0  ...                994.0  English       UK           PG-13
#
#         budget  title_year actor_2_facebook_likes imdb_score  aspect_ratio  \
# 0  237000000.0      2009.0                  936.0        7.9          1.78
# 1  300000000.0      2007.0                 5000.0        7.1          2.35
# 2  245000000.0      2015.0                  393.0        6.8          2.35
#
#   movie_facebook_likes
# 0              33000.0
# 1                  0.0
# 2              85000.0
#
# [3 rows x 28 columns]

# %% [markdown]
# # Indexing both the rows and columns

# %% [markdown]
# To slice only the features `movie_title` and `genres`, and the `first 3 rows`:

# %%
data[['movie_title', 'genres']].iloc[:3]
# Out:
#                                  movie_title                           genres
# 0                                    Avatar   Action|Adventure|Fantasy|Sci-Fi
# 1  Pirates of the Caribbean: At World's End          Action|Adventure|Fantasy
# 2                                   Spectre         Action|Adventure|Thriller

# %% [markdown]
# # Querying Data

# %% [markdown]
# ## Find Movies Starred by Orlando Bloom

# %%
obloom_films = data[data.actor_1_name == 'Orlando Bloom']
obloom_films
# Out:
#                                          movie_title  color  director_name  \
# 339   The Lord of the Rings: The Return of the King   Color  Peter Jackson
# 896                                   Elizabethtown   Color  Cameron Crowe
# 2591                                           Zulu   Color   Jérôme Salle
#
#       num_critic_for_reviews  duration  director_facebook_likes  \
# 339                    328.0     192.0                      0.0
# 896                    190.0     123.0                    488.0
# 2591                    69.0     110.0                     22.0
#
#       actor_3_facebook_likes     actor_2_name  actor_1_facebook_likes  \
# 339                    416.0       Billy Boyd                  5000.0
# 896                   2000.0    Kirsten Dunst                  5000.0
# 2591                    44.0  Tanya van Graan                  5000.0
#
#             gross  ... num_user_for_reviews language  country  content_rating  \
# 339   377019252.0  ...               3189.0  English      USA           PG-13
# 896    26838389.0  ...                495.0  English      USA           PG-13
# 2591          NaN  ...                 43.0  English   France               R
#
#           budget  title_year actor_2_facebook_likes imdb_score  aspect_ratio  \
# 339   94000000.0      2003.0                  857.0        8.9          2.35
# 896   57000000.0      2005.0                 4000.0        6.4          1.85
# 2591  16000000.0      2013.0                  170.0        6.7          2.35
#
#      movie_facebook_likes
# 339               16000.0
# 896                   0.0
# 2591                  0.0
#
# [3 rows x 28 columns]

# %% [markdown]
# Get the IMBD Scores and Content Rating of Movies Starred by Orlando Bloom

# %%
obloom_films[['imdb_score', 'content_rating']]
# Out:
#       imdb_score content_rating
# 339          8.9          PG-13
# 896          6.4          PG-13
# 2591         6.7              R

# %% [markdown]
# ## Sort films by gross earnings

# %%
top5_by_gross = data.sort_values(by="gross", ascending = False)
top5_by_gross[:5]
# Out:
#          movie_title  color    director_name  num_critic_for_reviews  \
# 0            Avatar   Color    James Cameron                   723.0
# 26          Titanic   Color    James Cameron                   315.0
# 29   Jurassic World   Color  Colin Trevorrow                   644.0
# 794    The Avengers   Color      Joss Whedon                   703.0
# 17     The Avengers   Color      Joss Whedon                   703.0
#
#      duration  director_facebook_likes  actor_3_facebook_likes  \
# 0       178.0                      0.0                   855.0
# 26      194.0                      0.0                   794.0
# 29      124.0                    365.0                  1000.0
# 794     173.0                      0.0                 19000.0
# 17      173.0                      0.0                 19000.0
#
#           actor_2_name  actor_1_facebook_likes        gross  ...  \
# 0     Joel David Moore                  1000.0  760505847.0  ...
# 26        Kate Winslet                 29000.0  658672302.0  ...
# 29          Judy Greer                  3000.0  652177271.0  ...
# 794  Robert Downey Jr.                 26000.0  623279547.0  ...
# 17   Robert Downey Jr.                 26000.0  623279547.0  ...
#
#     num_user_for_reviews language  country  content_rating       budget  \
# 0                 3054.0  English      USA           PG-13  237000000.0
# 26                2528.0  English      USA           PG-13  200000000.0
# 29                1290.0  English      USA           PG-13  150000000.0
# 794               1722.0  English      USA           PG-13  220000000.0
# 17                1722.0  English      USA           PG-13  220000000.0
#
#      title_year actor_2_facebook_likes imdb_score  aspect_ratio  \
# 0        2009.0                  936.0        7.9          1.78
# 26       1997.0                14000.0        7.7          2.35
# 29       2015.0                 2000.0        7.0          2.00
# 794      2012.0                21000.0        8.1          1.85
# 17       2012.0                21000.0        8.1          1.85
#
#     movie_facebook_likes
# 0                33000.0
# 26               26000.0
# 29              150000.0
# 794             123000.0
# 17              123000.0
#
# [5 rows x 28 columns]

# %% [markdown]
# ## Get the top 5 films of  Kate Winslet (in terms of gross earnings)

# %%
top5_by_gross[top5_by_gross['actor_1_name']=='Kate Winslet'][:3]
# Out:
#       movie_title  color     director_name  num_critic_for_reviews  duration  \
# 413    Divergent   Color       Neil Burger                   459.0     139.0
# 256    Insurgent   Color  Robert Schwentke                   263.0     119.0
# 408  The Holiday   Color      Nancy Meyers                   157.0     138.0
#
#      director_facebook_likes  actor_3_facebook_likes  actor_2_name  \
# 413                    168.0                  1000.0    Theo James
# 256                    124.0                  1000.0    Theo James
# 408                    278.0                   213.0  Rufus Sewell
#
#      actor_1_facebook_likes        gross  ... num_user_for_reviews language  \
# 413                 14000.0  150832203.0  ...                713.0  English
# 256                 14000.0  129995817.0  ...                258.0  English
# 408                 14000.0   63224849.0  ...                483.0  English
#
#      country  content_rating       budget  title_year actor_2_facebook_likes  \
# 413      USA           PG-13   85000000.0      2014.0                 5000.0
# 256      USA           PG-13  110000000.0      2015.0                 5000.0
# 408      USA           PG-13   85000000.0      2006.0                 3000.0
#
#     imdb_score  aspect_ratio movie_facebook_likes
# 413        6.7          2.35              49000.0
# 256        6.3          2.35              27000.0
# 408        6.9          1.85              19000.0
#
# [3 rows x 28 columns]

# %% [markdown]
# ## Multiple Conditions: Find films from Canada that have Bret Ratner as the director

# %%
canada = data['country']=='Canada'
ratner = data['director_name']=='Brett Ratner'

# %%
data[canada & ratner]
# Out:
#                movie_title  color director_name  num_critic_for_reviews  \
# 34  X-Men: The Last Stand   Color  Brett Ratner                   334.0
#
#     duration  director_facebook_likes  actor_3_facebook_likes    actor_2_name  \
# 34     104.0                    420.0                   560.0  Kelsey Grammer
#
#     actor_1_facebook_likes        gross  ... num_user_for_reviews language  \
# 34                 20000.0  234360014.0  ...               1912.0  English
#
#     country  content_rating       budget  title_year actor_2_facebook_likes  \
# 34   Canada           PG-13  210000000.0      2006.0                  808.0
#
#    imdb_score  aspect_ratio movie_facebook_likes
# 34        6.8          2.35                  0.0
#
# [1 rows x 28 columns]

# %% [markdown]
# You can rewrite it all in one line but would not be readable as you add more conditions.

# %%
data[(data['country']=='Canada') & (data['director_name']=='Brett Ratner')]
# Out:
#                movie_title  color director_name  num_critic_for_reviews  \
# 34  X-Men: The Last Stand   Color  Brett Ratner                   334.0
#
#     duration  director_facebook_likes  actor_3_facebook_likes    actor_2_name  \
# 34     104.0                    420.0                   560.0  Kelsey Grammer
#
#     actor_1_facebook_likes        gross  ... num_user_for_reviews language  \
# 34                 20000.0  234360014.0  ...               1912.0  English
#
#     country  content_rating       budget  title_year actor_2_facebook_likes  \
# 34   Canada           PG-13  210000000.0      2006.0                  808.0
#
#    imdb_score  aspect_ratio movie_facebook_likes
# 34        6.8          2.35                  0.0
#
# [1 rows x 28 columns]

# %% [markdown]
# ### Challenge 1: Find the actor who is the actor_1_name for the movie that grossed exactly 67344392.

# %%
data[data['gross']==67344392]['actor_1_name']
# Out:
# 347    Bruce Willis
# Name: actor_1_name, dtype: object

# %% [markdown]
# ### Challenge 2: Find films whose actor_3_name is Piolo Pascual

# %%
data[data['actor_3_name']=='Piolo Pascual']
# Out:
#               movie_title color   director_name  num_critic_for_reviews  \
# 5043  Starting Over Again   NaN  Olivia Lamasan                     NaN
#
#       duration  director_facebook_likes  actor_3_facebook_likes  actor_2_name  \
# 5043       NaN                      NaN                     NaN  Toni Gonzaga
#
#       actor_1_facebook_likes  gross  ... num_user_for_reviews language  \
# 5043                     NaN    NaN  ...                  NaN      NaN
#
#           country  content_rating budget  title_year actor_2_facebook_likes  \
# 5043  Philippines              PG    NaN      2014.0                    NaN
#
#      imdb_score  aspect_ratio movie_facebook_likes
# 5043        NaN           NaN                  NaN
#
# [1 rows x 28 columns]

# %% [markdown]
# ### Challenge 3: actor_1_name is the person from Armageddon.

# %%
armageddon = data[data['movie_title'].str.contains('Armageddon')]
armageddon_act = armageddon['actor_1_name'].tolist()
armageddon_act
# Out:
# ['Bruce Willis', 'Julian Sands']

# %% [markdown]
# # Data Preprocessing

# %%
data.dtypes
# Out:
# movie_title                   object
# color                         object
# director_name                 object
# num_critic_for_reviews       float64
# duration                     float64
# director_facebook_likes      float64
# actor_3_facebook_likes       float64
# actor_2_name                  object
# actor_1_facebook_likes       float64
# gross                        float64
# genres                        object
# actor_1_name                  object
# num_voted_users              float64
# cast_total_facebook_likes    float64
# actor_3_name                  object
# facenumber_in_poster         float64
# plot_keywords                 object
# movie_imdb_link               object
# num_user_for_reviews         float64
# language                      object
# country                       object
# content_rating                object
# budget                       float64
# title_year                   float64
# actor_2_facebook_likes       float64
# imdb_score                   float64
# aspect_ratio                 float64
# movie_facebook_likes         float64
# dtype: object

# %% [markdown]
# ## Convert actor_1_facebook likes to integers

# %% [markdown]
# data['actor_1_facebook_likes'] = data['actor_1_facebook_likes'].fillna(0)
# data['actor_1_facebook_likes'] = data['actor_1_facebook_likes'].astype(np.int64)
# data.dtypes

# %%
data['movie_title'].tolist()
# Out:
# ['Avatar\xa0',
#  "Pirates of the Caribbean: At World's End\xa0",
#  'Spectre\xa0',
#  'The Dark Knight Rises\xa0',
#  'Star Wars: Episode VII - The Force Awakens\xa0            ',
#  'John Carter\xa0',
#  'Spider-Man 3\xa0',
#  'Tangled\xa0',
#  'Avengers: Age of Ultron\xa0',
#  'Harry Potter and the Half-Blood Prince\xa0',
#  'Batman v Superman: Dawn of Justice\xa0',
#  'Superman Returns\xa0',
#  'Quantum of Solace\xa0',
#  "Pirates of the Caribbean: Dead Man's Chest\xa0",
#  'The Lone Ranger\xa0',
#  'Man of Steel\xa0',
#  'The Chronicles of Narnia: Prince Caspian\xa0',
#  'The Avengers\xa0',
#  'Pirates of the Caribbean: On Stranger Tides\xa0',
#  'Men in Black 3\xa0',
#  'The Hobbit: The Battle of the Five Armies\xa0',
#  'The Amazing Spider-Man\xa0',
#  'Robin Hood\xa0',
#  'The Hobbit: The Desolation of Smaug\xa0',
#  'The Golden Compass\xa0',
#  'King Kong\xa0',
#  'Titanic\xa0',
#  'Captain America: Civil War\xa0',
#  'Battleship\xa0',
#  'Jurassic World\xa0',
#  'Skyfall\xa0',
#  'Spider-Man 2\xa0',
#  'Iron Man 3\xa0',
#  'Alice in Wonderland\xa0',
#  'X-Men: The Last Stand\xa0',
#  'Monsters University\xa0',
#  'Transformers: Revenge of the Fallen\xa0',
#  'Transformers: Age of Extinction\xa0',
#  'Oz the Great and Powerful\xa0',
#  'The Amazing Spider-Man 2\xa0',
#  'TRON: Legacy\xa0',
#  'Cars 2\xa0',
#  'Green Lantern\xa0',
#  'Toy Story 3\xa0',
#  'Terminator Salvation\xa0',
#  'Furious 7\xa0',
#  'World War Z\xa0',
#  'X-Men: Days of Future Past\xa0',
#  'Star Trek Into Darkness\xa0',
#  'Jack the Giant Slayer\xa0',
#  'The Great Gatsby\xa0',
#  'Prince of Persia: The Sands of Time\xa0',
#  'Pacific Rim\xa0',
#  'Transformers: Dark of the Moon\xa0',
#  'Indiana Jones and the Kingdom of the Crystal Skull\xa0',
#  'The Good Dinosaur\xa0',
#  'Brave\xa0',
#  'Star Trek Beyond\xa0',
#  'WALL·E\xa0',
#  'Rush Hour 3\xa0',
#  '2012',
#  'A Christmas Carol\xa0',
#  'Jupiter Ascending\xa0',
#  'The Legend of Tarzan\xa0',
#  'The Chronicles of Narnia: The Lion, the Witch and the Wardrobe\xa0',
#  'X-Men: Apocalypse\xa0',
#  'The Dark Knight\xa0',
#  'Up\xa0',
#  'Monsters vs. Aliens\xa0',
#  'Iron Man\xa0',
#  'Hugo\xa0',
#  'Wild Wild West\xa0',
#  'The Mummy: Tomb of the Dragon Emperor\xa0',
#  'Suicide Squad\xa0',
#  'Evan Almighty\xa0',
#  'Edge of Tomorrow\xa0',
#  'Waterworld\xa0',
#  'G.I. Joe: The Rise of Cobra\xa0',
#  'Inside Out\xa0',
#  'The Jungle Book\xa0',
#  'Iron Man 2\xa0',
#  'Snow White and the Huntsman\xa0',
#  'Maleficent\xa0',
#  'Dawn of the Planet of the Apes\xa0',
#  'The Lovers\xa0',
#  '47 Ronin\xa0',
#  'Captain America: The Winter Soldier\xa0',
#  'Shrek Forever After\xa0',
#  'Tomorrowland\xa0',
#  'Big Hero 6\xa0',
#  'Wreck-It Ralph\xa0',
#  'The Polar Express\xa0',
#  'Independence Day: Resurgence\xa0',
#  'How to Train Your Dragon\xa0',
#  'Terminator 3: Rise of the Machines\xa0',
#  'Guardians of the Galaxy\xa0',
#  'Interstellar\xa0',
#  'Inception\xa0',
#  'Godzilla Resurgence\xa0',
#  'The Hobbit: An Unexpected Journey\xa0',
#  'The Fast and the Furious\xa0',
#  'The Curious Case of Benjamin Button\xa0',
#  'X-Men: First Class\xa0',
#  'The Hunger Games: Mockingjay - Part 2\xa0',
#  "The Sorcerer's Apprentice\xa0",
#  'Poseidon\xa0',
#  'Alice Through the Looking Glass\xa0',
#  'Shrek the Third\xa0',
#  'Warcraft\xa0',
#  'Terminator Genisys\xa0',
#  'The Chronicles of Narnia: The Voyage of the Dawn Treader\xa0',
#  'Pearl Harbor\xa0',
#  'Transformers\xa0',
#  'Alexander\xa0',
#  'Harry Potter and the Order of the Phoenix\xa0',
#  'Harry Potter and the Goblet of Fire\xa0',
#  'Hancock\xa0',
#  'I Am Legend\xa0',
#  'Charlie and the Chocolate Factory\xa0',
#  'Ratatouille\xa0',
#  'Batman Begins\xa0',
#  'Madagascar: Escape 2 Africa\xa0',
#  'Night at the Museum: Battle of the Smithsonian\xa0',
#  'X-Men Origins: Wolverine\xa0',
#  'The Matrix Revolutions\xa0',
#  'Frozen\xa0',
#  'The Matrix Reloaded\xa0',
#  'Thor: The Dark World\xa0',
#  'Mad Max: Fury Road\xa0',
#  'Angels & Demons\xa0',
#  'Thor\xa0',
#  'Bolt\xa0',
#  'G-Force\xa0',
#  'Wrath of the Titans\xa0',
#  'Dark Shadows\xa0',
#  'Mission: Impossible - Rogue Nation\xa0',
#  'The Wolfman\xa0',
#  'The Legend of Tarzan\xa0',
#  'Bee Movie\xa0',
#  'Kung Fu Panda 2\xa0',
#  'The Last Airbender\xa0',
#  'Mission: Impossible III\xa0',
#  'White House Down\xa0',
#  'Mars Needs Moms\xa0',
#  'Flushed Away\xa0',
#  'Pan\xa0',
#  'Mr. Peabody & Sherman\xa0',
#  'Troy\xa0',
#  "Madagascar 3: Europe's Most Wanted\xa0",
#  'Die Another Day\xa0',
#  'Ghostbusters\xa0',
#  'Armageddon\xa0',
#  'Men in Black II\xa0',
#  'Beowulf\xa0',
#  'Kung Fu Panda 3\xa0',
#  'Mission: Impossible - Ghost Protocol\xa0',
#  'Rise of the Guardians\xa0',
#  'Fun with Dick and Jane\xa0',
#  'The Last Samurai\xa0',
#  'Exodus: Gods and Kings\xa0',
#  'Star Trek\xa0',
#  'Spider-Man\xa0',
#  'How to Train Your Dragon 2\xa0',
#  'Gods of Egypt\xa0',
#  'Stealth\xa0',
#  'Watchmen\xa0',
#  'Lethal Weapon 4\xa0',
#  'Hulk\xa0',
#  'G.I. Joe: Retaliation\xa0',
#  'Sahara\xa0',
#  'Final Fantasy: The Spirits Within\xa0',
#  'Captain America: The First Avenger\xa0',
#  'The World Is Not Enough\xa0',
#  'Master and Commander: The Far Side of the World\xa0',
#  'The Twilight Saga: Breaking Dawn - Part 2\xa0',
#  'Happy Feet 2\xa0',
#  'The Incredible Hulk\xa0',
#  'Miami Vice\xa0            ',
#  'The BFG\xa0',
#  'The Revenant\xa0',
#  'Turbo\xa0',
#  'Rango\xa0',
#  'Penguins of Madagascar\xa0',
#  'The Bourne Ultimatum\xa0',
#  'Kung Fu Panda\xa0',
#  'Ant-Man\xa0',
#  'The Hunger Games: Catching Fire\xa0',
#  'The Twilight Saga: Breaking Dawn - Part 2\xa0',
#  'Home\xa0',
#  'War of the Worlds\xa0',
#  'Bad Boys II\xa0',
#  'Puss in Boots\xa0',
#  'Salt\xa0',
#  'Noah\xa0',
#  'The Adventures of Tintin\xa0',
#  'Harry Potter and the Prisoner of Azkaban\xa0',
#  'Australia\xa0',
#  'After Earth\xa0',
#  'Dinosaur\xa0',
#  'Harry Potter and the Deathly Hallows: Part II\xa0',
#  'Night at the Museum: Secret of the Tomb\xa0',
#  'Megamind\xa0',
#  "Harry Potter and the Sorcerer's Stone\xa0",
#  'R.I.P.D.\xa0',
#  'Godzilla Resurgence\xa0',
#  'Pirates of the Caribbean: The Curse of the Black Pearl\xa0',
#  'Harry Potter and the Deathly Hallows: Part I\xa0',
#  'The Hunger Games: Mockingjay - Part 1\xa0',
#  'The Da Vinci Code\xa0',
#  'Rio 2\xa0',
#  'X-Men 2\xa0',
#  'Fast Five\xa0',
#  'Sherlock Holmes: A Game of Shadows\xa0',
#  'Clash of the Titans\xa0',
#  'Total Recall\xa0',
#  'The 13th Warrior\xa0',
#  'The Bourne Legacy\xa0',
#  'Batman & Robin\xa0',
#  'How the Grinch Stole Christmas\xa0',
#  'The Day After Tomorrow\xa0',
#  'Mission: Impossible II\xa0',
#  'The Perfect Storm\xa0',
#  'Fantastic 4: Rise of the Silver Surfer\xa0',
#  'Life of Pi\xa0',
#  'Ghost Rider\xa0',
#  'Jason Bourne\xa0',
#  "Charlie's Angels: Full Throttle\xa0",
#  'Prometheus\xa0',
#  'Stuart Little 2\xa0',
#  'Elysium\xa0',
#  'The Chronicles of Riddick\xa0',
#  'RoboCop\xa0',
#  'Speed Racer\xa0',
#  'How Do You Know\xa0',
#  'Knight and Day\xa0',
#  'Oblivion\xa0',
#  'Star Wars: Episode III - Revenge of the Sith\xa0',
#  'Star Wars: Episode II - Attack of the Clones\xa0',
#  'Monsters, Inc.\xa0',
#  'The Wolverine\xa0',
#  'Star Wars: Episode I - The Phantom Menace\xa0',
#  'The Croods\xa0',
#  'Asterix at the Olympic Games\xa0',
#  'Windtalkers\xa0',
#  "The Huntsman: Winter's War\xa0",
#  'Teenage Mutant Ninja Turtles\xa0',
#  'Gravity\xa0',
#  "Dante's Peak\xa0",
#  'Teenage Mutant Ninja Turtles: Out of the Shadows\xa0',
#  'Fantastic Four\xa0',
#  'Night at the Museum\xa0',
#  'San Andreas\xa0',
#  'Tomorrow Never Dies\xa0',
#  'The Patriot\xa0',
#  "Ocean's Twelve\xa0",
#  'Mr. & Mrs. Smith\xa0',
#  'Insurgent\xa0',
#  'The Aviator\xa0',
#  "Gulliver's Travels\xa0",
#  'The Green Hornet\xa0',
#  'The A-Team\xa0            ',
#  '300: Rise of an Empire\xa0',
#  'The Smurfs\xa0',
#  'Home on the Range\xa0',
#  'Allegiant\xa0',
#  'Real Steel\xa0',
#  'The Smurfs 2\xa0',
#  'Speed 2: Cruise Control\xa0',
#  "Ender's Game\xa0",
#  'Live Free or Die Hard\xa0',
#  'The Lord of the Rings: The Fellowship of the Ring\xa0',
#  'Around the World in 80 Days\xa0',
#  'Ali\xa0',
#  'The Cat in the Hat\xa0',
#  'I, Robot\xa0',
#  'Kingdom of Heaven\xa0',
#  'Stuart Little\xa0',
#  'The Princess and the Frog\xa0',
#  'The Martian\xa0',
#  '10,000 B.C.\xa0            ',
#  'The Island\xa0',
#  'Town & Country\xa0',
#  'Gone in Sixty Seconds\xa0',
#  'Gladiator\xa0',
#  'Minority Report\xa0',
#  'Harry Potter and the Chamber of Secrets\xa0',
#  'Casino Royale\xa0',
#  'Planet of the Apes\xa0',
#  'Terminator 2: Judgment Day\xa0',
#  'Public Enemies\xa0',
#  'American Gangster\xa0',
#  'True Lies\xa0',
#  'The Taking of Pelham 1 2 3\xa0',
#  'Little Fockers\xa0',
#  'The Other Guys\xa0',
#  'Eraser\xa0',
#  'Django Unchained\xa0',
#  'The Hunchback of Notre Dame\xa0',
#  "The Emperor's New Groove\xa0",
#  'The Expendables 2\xa0',
#  'National Treasure\xa0',
#  'Eragon\xa0',
#  'Where the Wild Things Are\xa0',
#  'Pan\xa0',
#  'Epic\xa0',
#  'The Tourist\xa0',
#  'End of Days\xa0',
#  'Blood Diamond\xa0',
#  'The Wolf of Wall Street\xa0',
#  'Batman Forever\xa0',
#  'Starship Troopers\xa0',
#  'Cloud Atlas\xa0',
#  "Legend of the Guardians: The Owls of Ga'Hoole\xa0",
#  'Catwoman\xa0',
#  'Hercules\xa0',
#  'Treasure Planet\xa0',
#  'Land of the Lost\xa0',
#  'The Expendables 3\xa0',
#  'Point Break\xa0',
#  'Son of the Mask\xa0',
#  'In the Heart of the Sea\xa0',
#  'The Adventures of Pluto Nash\xa0',
#  'Green Zone\xa0',
#  'The Peanuts Movie\xa0',
#  'The Spanish Prisoner\xa0',
#  'The Mummy Returns\xa0',
#  'Gangs of New York\xa0',
#  'The Flowers of War\xa0',
#  "Surf's Up\xa0",
#  'The Stepford Wives\xa0',
#  'Black Hawk Down\xa0',
#  'The Campaign\xa0',
#  'The Fifth Element\xa0',
#  'Sex and the City 2\xa0',
#  'The Road to El Dorado\xa0',
#  'Ice Age: Continental Drift\xa0',
#  'Cinderella\xa0',
#  'The Lovely Bones\xa0',
#  'Finding Nemo\xa0',
#  'The Lord of the Rings: The Return of the King\xa0',
#  'The Lord of the Rings: The Two Towers\xa0',
#  'Seventh Son\xa0',
#  'Lara Croft: Tomb Raider\xa0',
#  'Transcendence\xa0',
#  'Jurassic Park III\xa0',
#  'Rise of the Planet of the Apes\xa0',
#  'The Spiderwick Chronicles\xa0',
#  'A Good Day to Die Hard\xa0',
#  'The Alamo\xa0',
#  'The Incredibles\xa0',
#  'Cutthroat Island\xa0',
#  'Percy Jackson & the Olympians: The Lightning Thief\xa0',
#  'Men in Black\xa0',
#  'Toy Story 2\xa0',
#  'Unstoppable\xa0',
#  'Rush Hour 2\xa0',
#  'What Lies Beneath\xa0',
#  'Cloudy with a Chance of Meatballs\xa0',
#  'Ice Age: Dawn of the Dinosaurs\xa0',
#  'The Secret Life of Walter Mitty\xa0',
#  "Charlie's Angels\xa0",
#  'The Departed\xa0',
#  'Mulan\xa0',
#  'Tropic Thunder\xa0',
#  'The Girl with the Dragon Tattoo\xa0',
#  'Die Hard with a Vengeance\xa0',
#  'Sherlock Holmes\xa0',
#  'Ben-Hur\xa0',
#  'Atlantis: The Lost Empire\xa0',
#  'Alvin and the Chipmunks: The Road Chip\xa0',
#  'Valkyrie\xa0',
#  "You Don't Mess with the Zohan\xa0",
#  'Pixels\xa0',
#  'A.I. Artificial Intelligence\xa0',
#  'The Haunted Mansion\xa0',
#  'Contact\xa0',
#  'Hollow Man\xa0',
#  'The Interpreter\xa0',
#  'Percy Jackson: Sea of Monsters\xa0',
#  'Lara Croft Tomb Raider: The Cradle of Life\xa0',
#  'Now You See Me 2\xa0',
#  'The Saint\xa0',
#  'Spy Game\xa0',
#  'Mission to Mars\xa0',
#  'Rio\xa0',
#  'Bicentennial Man\xa0',
#  'Volcano\xa0',
#  "The Devil's Own\xa0",
#  'K-19: The Widowmaker\xa0',
#  'Fantastic Four\xa0',
#  'Conan the Barbarian\xa0',
#  'Cinderella Man\xa0',
#  'The Nutcracker in 3D\xa0',
#  'Seabiscuit\xa0',
#  'Twister\xa0',
#  'The Fast and the Furious\xa0',
#  'Cast Away\xa0',
#  'Happy Feet\xa0',
#  'The Bourne Supremacy\xa0',
#  'Air Force One\xa0',
#  "Ocean's Eleven\xa0",
#  'The Three Musketeers\xa0',
#  'Hotel Transylvania\xa0',
#  'Enchanted\xa0',
#  'Hannibal\xa0            ',
#  'Safe House\xa0',
#  '102 Dalmatians\xa0',
#  'Tower Heist\xa0',
#  'The Holiday\xa0',
#  'Enemy of the State\xa0',
#  "It's Complicated\xa0",
#  "Ocean's Thirteen\xa0",
#  'Open Season\xa0',
#  'Divergent\xa0',
#  'Enemy at the Gates\xa0',
#  'The Rundown\xa0',
#  'Last Action Hero\xa0',
#  'Memoirs of a Geisha\xa0',
#  'The Fast and the Furious: Tokyo Drift\xa0',
#  'Arthur Christmas\xa0',
#  'Meet Joe Black\xa0',
#  'Collateral Damage\xa0',
#  'All That Jazz\xa0',
#  'Mirror Mirror\xa0',
#  'Scott Pilgrim vs. the World\xa0',
#  'The Core\xa0',
#  'Nutty Professor II: The Klumps\xa0',
#  'Scooby-Doo\xa0',
#  'Dredd\xa0',
#  'Click\xa0',
#  'Creepshow\xa0',
#  'Cats & Dogs: The Revenge of Kitty Galore\xa0',
#  'Jumper\xa0',
#  'Hellboy II: The Golden Army\xa0',
#  'Zodiac\xa0',
#  'The 6th Day\xa0',
#  'Bruce Almighty\xa0',
#  'The Expendables\xa0',
#  'Mission: Impossible\xa0',
#  'The Hunger Games\xa0',
#  'The Hangover Part II\xa0',
#  'Batman Returns\xa0',
#  'Over the Hedge\xa0',
#  'Lilo & Stitch\xa0',
#  "Charlotte's Web\xa0",
#  'Deep Impact\xa0',
#  'RED 2\xa0',
#  'The Longest Yard\xa0',
#  'Alvin and the Chipmunks: Chipwrecked\xa0',
#  'Grown Ups 2\xa0',
#  'Get Smart\xa0',
#  "Something's Gotta Give\xa0",
#  'Shutter Island\xa0',
#  'Four Christmases\xa0',
#  'Robots\xa0',
#  'Face/Off\xa0',
#  'Bedtime Stories\xa0',
#  'Road to Perdition\xa0',
#  'Just Go with It\xa0',
#  'Daredevil\xa0            ',
#  'Con Air\xa0',
#  'Eagle Eye\xa0',
#  'Cold Mountain\xa0',
#  'The Book of Eli\xa0',
#  'Flubber\xa0',
#  'The Haunting\xa0',
#  'Space Jam\xa0',
#  'The Pink Panther\xa0',
#  'The Day the Earth Stood Still\xa0',
#  'Conspiracy Theory\xa0',
#  'Fury\xa0',
#  'Six Days Seven Nights\xa0',
#  'Yogi Bear\xa0',
#  'Spirit: Stallion of the Cimarron\xa0',
#  'Zookeeper\xa0',
#  'Lost in Space\xa0',
#  'The Manchurian Candidate\xa0',
#  'Déjà Vu\xa0',
#  'Hotel Transylvania 2\xa0',
#  'Bewitched\xa0            ',
#  'Fantasia 2000\xa0',
#  'The Time Machine\xa0',
#  'Mighty Joe Young\xa0',
#  'Swordfish\xa0',
#  'The Legend of Zorro\xa0',
#  'What Dreams May Come\xa0',
#  'Little Nicky\xa0',
#  'The Brothers Grimm\xa0',
#  'Mars Attacks!\xa0',
#  'Evolution\xa0',
#  'The Edge\xa0',
#  'Surrogates\xa0',
#  'Thirteen Days\xa0',
#  'Daylight\xa0',
#  'Walking with Dinosaurs 3D\xa0',
#  'Battlefield Earth\xa0',
#  'Looney Tunes: Back in Action\xa0',
#  'Nine\xa0',
#  'Timeline\xa0',
#  'The Postman\xa0',
#  'Babe: Pig in the City\xa0',
#  'The Last Witch Hunter\xa0',
#  'Red Planet\xa0',
#  'Arthur and the Invisibles\xa0',
#  'Oceans\xa0',
#  'A Sound of Thunder\xa0',
#  'Pompeii\xa0',
#  'Top Cat Begins\xa0',
#  'A Beautiful Mind\xa0',
#  'The Lion King\xa0',
#  'Journey 2: The Mysterious Island\xa0',
#  'Cloudy with a Chance of Meatballs 2\xa0',
#  'Red Dragon\xa0',
#  'Hidalgo\xa0',
#  'Jack and Jill\xa0',
#  '2 Fast 2 Furious\xa0',
#  'The Little Prince\xa0',
#  'The Invasion\xa0',
#  'The Adventures of Rocky & Bullwinkle\xa0',
#  'The Secret Life of Pets\xa0',
#  'The League of Extraordinary Gentlemen\xa0',
#  'Despicable Me 2\xa0',
#  'Independence Day\xa0',
#  'The Lost World: Jurassic Park\xa0',
#  'Madagascar\xa0',
#  'Children of Men\xa0',
#  'X-Men\xa0',
#  'Wanted\xa0',
#  'The Rock\xa0',
#  'Ice Age: The Meltdown\xa0',
#  '50 First Dates\xa0',
#  'Hairspray\xa0',
#  'Exorcist: The Beginning\xa0',
#  'Inspector Gadget\xa0',
#  'Now You See Me\xa0',
#  'Grown Ups\xa0',
#  'The Terminal\xa0',
#  'Constantine\xa0            ',
#  'Hotel for Dogs\xa0',
#  'Vertical Limit\xa0',
#  "Charlie Wilson's War\xa0",
#  'Shark Tale\xa0',
#  'Dreamgirls\xa0',
#  'Life\xa0            ',
#  'Be Cool\xa0',
#  'Munich\xa0',
#  'Tears of the Sun\xa0',
#  'Killers\xa0',
#  'The Man from U.N.C.L.E.\xa0',
#  'Spanglish\xa0',
#  'Monster House\xa0',
#  'Bandits\xa0',
#  'First Knight\xa0',
#  'Anna and the King\xa0',
#  'Immortals\xa0',
#  'Hostage\xa0',
#  'Titan A.E.\xa0',
#  'Hollywood Homicide\xa0',
#  'Soldier\xa0',
#  'Carriers\xa0',
#  'Monkeybone\xa0',
#  'Flight of the Phoenix\xa0',
#  'Unbreakable\xa0',
#  'Minions\xa0',
#  'Sucker Punch\xa0',
#  'Snake Eyes\xa0',
#  'Sphere\xa0',
#  'The Angry Birds Movie\xa0',
#  "Fool's Gold\xa0",
#  'Funny People\xa0',
#  'The Kingdom\xa0',
#  'Talladega Nights: The Ballad of Ricky Bobby\xa0',
#  'Dr. Dolittle 2\xa0',
#  'Braveheart\xa0',
#  'Jarhead\xa0',
#  'The Simpsons Movie\xa0',
#  'The Majestic\xa0',
#  'Driven\xa0',
#  'Two Brothers\xa0',
#  'The Village\xa0',
#  'Doctor Dolittle\xa0',
#  'Signs\xa0',
#  'Shrek 2\xa0',
#  'Cars\xa0',
#  'Runaway Bride\xa0',
#  'xXx\xa0',
#  'The SpongeBob Movie: Sponge Out of Water\xa0',
#  'Ransom\xa0',
#  'Inglourious Basterds\xa0',
#  'Hook\xa0',
#  'Hercules\xa0',
#  'Die Hard 2\xa0',
#  'S.W.A.T.\xa0',
#  'Sleepy Hollow\xa0            ',
#  'Vanilla Sky\xa0',
#  'Lady in the Water\xa0',
#  'AVP: Alien vs. Predator\xa0',
#  'Alvin and the Chipmunks: The Squeakquel\xa0',
#  'We Were Soldiers\xa0',
#  'Olympus Has Fallen\xa0',
#  'Star Trek: Insurrection\xa0',
#  'Battle Los Angeles\xa0',
#  'Big Fish\xa0',
#  'Wolf\xa0',
#  'War Horse\xa0',
#  'The Monuments Men\xa0',
#  'The Abyss\xa0',
#  'Wall Street: Money Never Sleeps\xa0',
#  'Dracula Untold\xa0',
#  'The Siege\xa0',
#  'Stardust\xa0',
#  'Seven Years in Tibet\xa0',
#  'The Dilemma\xa0',
#  'Bad Company\xa0',
#  'Doom\xa0',
#  'I Spy\xa0',
#  'Underworld: Awakening\xa0',
#  'Rock of Ages\xa0',
#  "Hart's War\xa0",
#  'Killer Elite\xa0',
#  'Rollerball\xa0',
#  'Ballistic: Ecks vs. Sever\xa0',
#  'Hard Rain\xa0',
#  'Osmosis Jones\xa0',
#  "Legends of Oz: Dorothy's Return\xa0",
#  'Blackhat\xa0',
#  'Sky Captain and the World of Tomorrow\xa0',
#  'Basic Instinct 2\xa0',
#  'Escape Plan\xa0',
#  'The Legend of Hercules\xa0',
#  'The Sum of All Fears\xa0',
#  'The Twilight Saga: Eclipse\xa0',
#  'The Score\xa0',
#  'Despicable Me\xa0',
#  'Money Train\xa0',
#  'Ted 2\xa0',
#  'Agora\xa0',
#  'Mystery Men\xa0',
#  'Hall Pass\xa0',
#  'The Insider\xa0',
#  'The Finest Hours\xa0',
#  'Body of Lies\xa0',
#  'Dinner for Schmucks\xa0',
#  'Abraham Lincoln: Vampire Hunter\xa0',
#  'Entrapment\xa0',
#  'Last Man Standing\xa0            ',
#  'The X Files\xa0',
#  'The Last Legion\xa0',
#  'Saving Private Ryan\xa0',
#  'Need for Speed\xa0',
#  'What Women Want\xa0',
#  'Ice Age\xa0',
#  'Dreamcatcher\xa0',
#  'Lincoln\xa0',
#  'The Matrix\xa0',
#  'Apollo 13\xa0',
#  'Total Recall\xa0',
#  'The Santa Clause 2\xa0',
#  'Les Misérables\xa0',
#  "You've Got Mail\xa0",
#  'Step Brothers\xa0',
#  'The Mask of Zorro\xa0',
#  'Due Date\xa0',
#  'Unbroken\xa0',
#  'Space Cowboys\xa0',
#  'Cliffhanger\xa0',
#  'Broken Arrow\xa0',
#  'The Kid\xa0',
#  'World Trade Center\xa0',
#  'Mona Lisa Smile\xa0',
#  'The Dictator\xa0',
#  'Eyes Wide Shut\xa0',
#  'Annie\xa0',
#  'Focus\xa0',
#  'This Means War\xa0',
#  'Blade: Trinity\xa0',
#  'Red Dawn\xa0',
#  'Primary Colors\xa0',
#  'Resident Evil: Retribution\xa0',
#  'Death Race\xa0',
#  'The Long Kiss Goodnight\xa0',
#  'Proof of Life\xa0',
#  'Zathura: A Space Adventure\xa0',
#  'Fight Club\xa0',
#  'We Are Marshall\xa0',
#  'The Missing\xa0            ',
#  'Hudson Hawk\xa0',
#  'Lucky Numbers\xa0',
#  'I, Frankenstein\xa0',
#  'Oliver Twist\xa0',
#  'Elektra\xa0',
#  'Sin City: A Dame to Kill For\xa0',
#  'Random Hearts\xa0',
#  'Everest\xa0',
#  'Perfume: The Story of a Murderer\xa0',
#  'Austin Powers in Goldmember\xa0',
#  'Astro Boy\xa0',
#  'Jurassic Park\xa0',
#  'Wyatt Earp\xa0',
#  'Clear and Present Danger\xa0',
#  'Dragon Blade\xa0',
#  'Littleman\xa0',
#  'U-571\xa0',
#  'The American President\xa0',
#  'The Love Guru\xa0',
#  '3000 Miles to Graceland\xa0',
#  'The Hateful Eight\xa0',
#  'Blades of Glory\xa0',
#  'Hop\xa0',
#  '300',
#  'Meet the Fockers\xa0',
#  'Marley & Me\xa0',
#  'The Green Mile\xa0',
#  'Wild Hogs\xa0',
#  'Chicken Little\xa0',
#  'Gone Girl\xa0',
#  'The Bourne Identity\xa0',
#  'GoldenEye\xa0',
#  "The General's Daughter\xa0",
#  'The Truman Show\xa0',
#  'The Prince of Egypt\xa0',
#  'Daddy Day Care\xa0',
#  '2 Guns\xa0',
#  'Cats & Dogs\xa0',
#  'The Italian Job\xa0',
#  'Two Weeks Notice\xa0',
#  'Antz\xa0',
#  'Couples Retreat\xa0',
#  'Days of Thunder\xa0',
#  'Cheaper by the Dozen 2\xa0',
#  'The Scorch Trials\xa0',
#  'Eat Pray Love\xa0',
#  'The Family Man\xa0',
#  'RED\xa0',
#  'Any Given Sunday\xa0',
#  'The Horse Whisperer\xa0',
#  'Collateral\xa0',
#  'The Scorpion King\xa0',
#  'Ladder 49\xa0',
#  'Jack Reacher\xa0',
#  'Deep Blue Sea\xa0',
#  'This Is It\xa0',
#  'Contagion\xa0',
#  'Kangaroo Jack\xa0',
#  'Coraline\xa0',
#  'The Happening\xa0',
#  'Man on Fire\xa0',
#  'The Shaggy Dog\xa0',
#  'Starsky & Hutch\xa0',
#  'Jingle All the Way\xa0',
#  'Hellboy\xa0',
#  'A Civil Action\xa0',
#  'ParaNorman\xa0',
#  'The Jackal\xa0',
#  'Paycheck\xa0',
#  'Up Close & Personal\xa0',
#  'The Tale of Despereaux\xa0',
#  'Rules of Engagement\xa0            ',
#  'The Tuxedo\xa0',
#  'Under Siege 2: Dark Territory\xa0',
#  'Jack Ryan: Shadow Recruit\xa0',
#  'Joy\xa0',
#  'London Has Fallen\xa0',
#  'Alien: Resurrection\xa0',
#  'Shooter\xa0',
#  'The Boxtrolls\xa0',
#  'Practical Magic\xa0',
#  'The Lego Movie\xa0',
#  'Miss Congeniality 2: Armed and Fabulous\xa0',
#  'Reign of Fire\xa0',
#  'Gangster Squad\xa0',
#  'Year One\xa0',
#  'Invictus\xa0',
#  'State of Play\xa0',
#  'Duplicity\xa0',
#  'My Favorite Martian\xa0',
#  'The Sentinel\xa0',
#  'Planet 51\xa0',
#  'Star Trek: Nemesis\xa0',
#  'Intolerable Cruelty\xa0',
#  'Trouble with the Curve\xa0',
#  'Edge of Darkness\xa0',
#  'The Relic\xa0',
#  'Analyze That\xa0',
#  'Righteous Kill\xa0',
#  'Mercury Rising\xa0',
#  'The Soloist\xa0',
#  'The Legend of Bagger Vance\xa0',
#  'Almost Famous\xa0',
#  'Garfield 2\xa0',
#  'xXx: State of the Union\xa0',
#  'Priest\xa0',
#  'Sinbad: Legend of the Seven Seas\xa0',
#  'Event Horizon\xa0',
#  'The Avengers\xa0',
#  'Dragonfly\xa0',
#  'The Black Dahlia\xa0',
#  'Flyboys\xa0',
#  'The Last Castle\xa0',
#  'Supernova\xa0',
#  "Winter's Tale\xa0",
#  'The Mortal Instruments: City of Bones\xa0',
#  'Meet Dave\xa0',
#  'Dark Water\xa0',
#  'Edtv\xa0',
#  'Inkheart\xa0',
#  'The Spirit\xa0',
#  'Mortdecai\xa0',
#  'In the Name of the King: A Dungeon Siege Tale\xa0',
#  'Beyond Borders\xa0',
#  'Xi you ji zhi: Sun Wukong san da Baigu Jing\xa0',
#  'The Great Raid\xa0',
#  'Deadpool\xa0',
#  'Holy Man\xa0',
#  'American Sniper\xa0',
#  'Goosebumps\xa0',
#  'Sabrina, the Teenage Witch\xa0            ',
#  'Just Like Heaven\xa0',
#  'The Flintstones in Viva Rock Vegas\xa0',
#  'Rambo III\xa0',
#  'Leatherheads\xa0',
#  'The Ridiculous 6\xa0',
#  'Did You Hear About the Morgans?\xa0',
#  'The Internship\xa0',
#  'Resident Evil: Afterlife\xa0',
#  'Red Tails\xa0',
#  'Sex and the City\xa0            ',
#  "The Devil's Advocate\xa0",
#  "That's My Boy\xa0",
#  'DragonHeart\xa0',
#  'After the Sunset\xa0',
#  'Ghost Rider: Spirit of Vengeance\xa0',
#  "Captain Corelli's Mandolin\xa0",
#  'Anger Management\xa0            ',
#  'The Pacifier\xa0',
#  'Walking Tall\xa0',
#  'Forrest Gump\xa0',
#  'Alvin and the Chipmunks\xa0',
#  'Meet the Parents\xa0',
#  'Pocahontas\xa0',
#  'Superman\xa0',
#  'The Nutty Professor\xa0',
#  'Hitch\xa0',
#  'George of the Jungle\xa0',
#  'American Wedding\xa0',
#  'Captain Phillips\xa0',
#  'Date Night\xa0',
#  'Casper\xa0',
#  'The Equalizer\xa0',
#  'Maid in Manhattan\xa0',
#  'Crimson Tide\xa0',
#  'The Pursuit of Happyness\xa0',
#  'Flightplan\xa0',
#  'Disclosure\xa0',
#  'City of Angels\xa0',
#  'Kill Bill: Vol. 1\xa0',
#  'Bowfinger\xa0',
#  'Stargate SG-1\xa0            ',
#  'Kill Bill: Vol. 2\xa0',
#  'Tango & Cash\xa0',
#  'Death Becomes Her\xa0',
#  'Shanghai Noon\xa0',
#  'Executive Decision\xa0',
#  "Mr. Popper's Penguins\xa0",
#  'The Forbidden Kingdom\xa0',
#  'Free Birds\xa0',
#  'Alien 3\xa0',
#  'Evita\xa0',
#  'Ronin\xa0',
#  'The Ghost and the Darkness\xa0',
#  'Paddington\xa0',
#  'The Watch\xa0',
#  'The Hunted\xa0',
#  'Instinct\xa0',
#  'Stuck on You\xa0',
#  'Semi-Pro\xa0',
#  'The Pirates! Band of Misfits\xa0',
#  'Changeling\xa0',
#  'Chain Reaction\xa0',
#  'The Fan\xa0',
#  'The Phantom of the Opera\xa0',
#  'Elizabeth: The Golden Age\xa0',
#  'Æon Flux\xa0',
#  'Gods and Generals\xa0',
#  'Turbulence\xa0',
#  'Imagine That\xa0',
#  'Muppets Most Wanted\xa0',
#  'Thunderbirds\xa0',
#  'Burlesque\xa0',
#  'A Very Long Engagement\xa0',
#  'Lolita\xa0',
#  'Eye See You\xa0',
#  'Blade II\xa0',
#  'Seven Pounds\xa0',
#  'Bullet to the Head\xa0',
#  'The Godfather: Part III\xa0',
#  'Elizabethtown\xa0',
#  'You, Me and Dupree\xa0',
#  'Superman II\xa0',
#  'Gigli\xa0',
#  "All the King's Men\xa0",
#  'Shaft\xa0',
#  'Anastasia\xa0',
#  'Moulin Rouge!\xa0',
#  'Domestic Disturbance\xa0',
#  'Black Mass\xa0',
#  'Flags of Our Fathers\xa0',
#  'Law Abiding Citizen\xa0',
#  'Grindhouse\xa0',
#  'Beloved\xa0',
#  'Lucky You\xa0',
#  'Catch Me If You Can\xa0',
#  'Zero Dark Thirty\xa0',
#  'The Break-Up\xa0',
#  'Mamma Mia!\xa0',
#  "Valentine's Day\xa0",
#  'The Dukes of Hazzard\xa0',
#  'The Thin Red Line\xa0',
#  'The Change-Up\xa0',
#  'Man on the Moon\xa0',
#  'Casino\xa0',
#  'From Paris with Love\xa0',
#  'Bulletproof Monk\xa0',
#  'Me, Myself & Irene\xa0',
#  'Barnyard\xa0',
#  'Deck the Halls\xa0',
#  'The Twilight Saga: New Moon\xa0',
#  'Shrek\xa0',
#  'The Adjustment Bureau\xa0',
#  'Robin Hood: Prince of Thieves\xa0',
#  'Jerry Maguire\xa0',
#  'Ted\xa0',
#  'As Good as It Gets\xa0',
#  'Patch Adams\xa0',
#  'Anchorman 2: The Legend Continues\xa0',
#  'Mr. Deeds\xa0',
#  'Super 8\xa0',
#  'Erin Brockovich\xa0',
#  'How to Lose a Guy in 10 Days\xa0',
#  '22 Jump Street\xa0',
#  'Interview with the Vampire: The Vampire Chronicles\xa0',
#  'Yes Man\xa0',
#  'Central Intelligence\xa0',
#  'Stepmom\xa0',
#  "Daddy's Home\xa0",
#  'Into the Woods\xa0',
#  'Inside Man\xa0',
#  'Payback\xa0',
#  'Congo\xa0',
#  'We Bought a Zoo\xa0',
#  'Knowing\xa0',
#  'Failure to Launch\xa0',
#  'The Ring Two\xa0',
#  'Crazy, Stupid, Love.\xa0',
#  'Garfield\xa0',
#  'Christmas with the Kranks\xa0',
#  'Moneyball\xa0',
#  'Outbreak\xa0',
#  'Non-Stop\xa0',
#  'Race to Witch Mountain\xa0',
#  'V for Vendetta\xa0',
#  'Shanghai Knights\xa0',
#  'Unforgotten\xa0            ',
#  'Curious George\xa0',
#  'Herbie Fully Loaded\xa0',
#  "Don't Say a Word\xa0",
#  'Hansel & Gretel: Witch Hunters\xa0',
#  'Unfaithful\xa0',
#  'I Am Number Four\xa0',
#  'Syriana\xa0',
#  '13 Hours\xa0',
#  'The Book of Life\xa0',
#  'Firewall\xa0',
#  'Absolute Power\xa0',
#  'G.I. Jane\xa0',
#  'The Game\xa0',
#  'Silent Hill\xa0',
#  'The Replacements\xa0',
#  'American Reunion\xa0',
#  'The Negotiator\xa0',
#  'Into the Storm\xa0',
#  'Beverly Hills Cop III\xa0',
#  'Gremlins 2: The New Batch\xa0',
#  'The Judge\xa0',
#  'The Peacemaker\xa0',
#  'Resident Evil: Apocalypse\xa0',
#  'Bridget Jones: The Edge of Reason\xa0',
#  'Out of Time\xa0',
#  'On Deadly Ground\xa0',
#  'The Adventures of Sharkboy and Lavagirl 3-D\xa0',
#  'The Beach\xa0',
#  'Raising Helen\xa0',
#  'Ninja Assassin\xa0',
#  'For Love of the Game\xa0',
#  'A Touch of Frost\xa0            ',
#  'Striptease\xa0',
#  'Marmaduke\xa0',
#  'Hereafter\xa0',
#  'Murder by Numbers\xa0',
#  'Assassins\xa0',
#  ...]

# %%
data['movie_title'].apply(
    lambda x: x.encode()
    .decode('unicode_escape')
    .encode('ascii','ignore')).tolist()
# Out:
# [b'Avatar',
#  b"Pirates of the Caribbean: At World's End",
#  b'Spectre',
#  b'The Dark Knight Rises',
#  b'Star Wars: Episode VII - The Force Awakens            ',
#  b'John Carter',
#  b'Spider-Man 3',
#  b'Tangled',
#  b'Avengers: Age of Ultron',
#  b'Harry Potter and the Half-Blood Prince',
#  b'Batman v Superman: Dawn of Justice',
#  b'Superman Returns',
#  b'Quantum of Solace',
#  b"Pirates of the Caribbean: Dead Man's Chest",
#  b'The Lone Ranger',
#  b'Man of Steel',
#  b'The Chronicles of Narnia: Prince Caspian',
#  b'The Avengers',
#  b'Pirates of the Caribbean: On Stranger Tides',
#  b'Men in Black 3',
#  b'The Hobbit: The Battle of the Five Armies',
#  b'The Amazing Spider-Man',
#  b'Robin Hood',
#  b'The Hobbit: The Desolation of Smaug',
#  b'The Golden Compass',
#  b'King Kong',
#  b'Titanic',
#  b'Captain America: Civil War',
#  b'Battleship',
#  b'Jurassic World',
#  b'Skyfall',
#  b'Spider-Man 2',
#  b'Iron Man 3',
#  b'Alice in Wonderland',
#  b'X-Men: The Last Stand',
#  b'Monsters University',
#  b'Transformers: Revenge of the Fallen',
#  b'Transformers: Age of Extinction',
#  b'Oz the Great and Powerful',
#  b'The Amazing Spider-Man 2',
#  b'TRON: Legacy',
#  b'Cars 2',
#  b'Green Lantern',
#  b'Toy Story 3',
#  b'Terminator Salvation',
#  b'Furious 7',
#  b'World War Z',
#  b'X-Men: Days of Future Past',
#  b'Star Trek Into Darkness',
#  b'Jack the Giant Slayer',
#  b'The Great Gatsby',
#  b'Prince of Persia: The Sands of Time',
#  b'Pacific Rim',
#  b'Transformers: Dark of the Moon',
#  b'Indiana Jones and the Kingdom of the Crystal Skull',
#  b'The Good Dinosaur',
#  b'Brave',
#  b'Star Trek Beyond',
#  b'WALLE',
#  b'Rush Hour 3',
#  b'2012',
#  b'A Christmas Carol',
#  b'Jupiter Ascending',
#  b'The Legend of Tarzan',
#  b'The Chronicles of Narnia: The Lion, the Witch and the Wardrobe',
#  b'X-Men: Apocalypse',
#  b'The Dark Knight',
#  b'Up',
#  b'Monsters vs. Aliens',
#  b'Iron Man',
#  b'Hugo',
#  b'Wild Wild West',
#  b'The Mummy: Tomb of the Dragon Emperor',
#  b'Suicide Squad',
#  b'Evan Almighty',
#  b'Edge of Tomorrow',
#  b'Waterworld',
#  b'G.I. Joe: The Rise of Cobra',
#  b'Inside Out',
#  b'The Jungle Book',
#  b'Iron Man 2',
#  b'Snow White and the Huntsman',
#  b'Maleficent',
#  b'Dawn of the Planet of the Apes',
#  b'The Lovers',
#  b'47 Ronin',
#  b'Captain America: The Winter Soldier',
#  b'Shrek Forever After',
#  b'Tomorrowland',
#  b'Big Hero 6',
#  b'Wreck-It Ralph',
#  b'The Polar Express',
#  b'Independence Day: Resurgence',
#  b'How to Train Your Dragon',
#  b'Terminator 3: Rise of the Machines',
#  b'Guardians of the Galaxy',
#  b'Interstellar',
#  b'Inception',
#  b'Godzilla Resurgence',
#  b'The Hobbit: An Unexpected Journey',
#  b'The Fast and the Furious',
#  b'The Curious Case of Benjamin Button',
#  b'X-Men: First Class',
#  b'The Hunger Games: Mockingjay - Part 2',
#  b"The Sorcerer's Apprentice",
#  b'Poseidon',
#  b'Alice Through the Looking Glass',
#  b'Shrek the Third',
#  b'Warcraft',
#  b'Terminator Genisys',
#  b'The Chronicles of Narnia: The Voyage of the Dawn Treader',
#  b'Pearl Harbor',
#  b'Transformers',
#  b'Alexander',
#  b'Harry Potter and the Order of the Phoenix',
#  b'Harry Potter and the Goblet of Fire',
#  b'Hancock',
#  b'I Am Legend',
#  b'Charlie and the Chocolate Factory',
#  b'Ratatouille',
#  b'Batman Begins',
#  b'Madagascar: Escape 2 Africa',
#  b'Night at the Museum: Battle of the Smithsonian',
#  b'X-Men Origins: Wolverine',
#  b'The Matrix Revolutions',
#  b'Frozen',
#  b'The Matrix Reloaded',
#  b'Thor: The Dark World',
#  b'Mad Max: Fury Road',
#  b'Angels & Demons',
#  b'Thor',
#  b'Bolt',
#  b'G-Force',
#  b'Wrath of the Titans',
#  b'Dark Shadows',
#  b'Mission: Impossible - Rogue Nation',
#  b'The Wolfman',
#  b'The Legend of Tarzan',
#  b'Bee Movie',
#  b'Kung Fu Panda 2',
#  b'The Last Airbender',
#  b'Mission: Impossible III',
#  b'White House Down',
#  b'Mars Needs Moms',
#  b'Flushed Away',
#  b'Pan',
#  b'Mr. Peabody & Sherman',
#  b'Troy',
#  b"Madagascar 3: Europe's Most Wanted",
#  b'Die Another Day',
#  b'Ghostbusters',
#  b'Armageddon',
#  b'Men in Black II',
#  b'Beowulf',
#  b'Kung Fu Panda 3',
#  b'Mission: Impossible - Ghost Protocol',
#  b'Rise of the Guardians',
#  b'Fun with Dick and Jane',
#  b'The Last Samurai',
#  b'Exodus: Gods and Kings',
#  b'Star Trek',
#  b'Spider-Man',
#  b'How to Train Your Dragon 2',
#  b'Gods of Egypt',
#  b'Stealth',
#  b'Watchmen',
#  b'Lethal Weapon 4',
#  b'Hulk',
#  b'G.I. Joe: Retaliation',
#  b'Sahara',
#  b'Final Fantasy: The Spirits Within',
#  b'Captain America: The First Avenger',
#  b'The World Is Not Enough',
#  b'Master and Commander: The Far Side of the World',
#  b'The Twilight Saga: Breaking Dawn - Part 2',
#  b'Happy Feet 2',
#  b'The Incredible Hulk',
#  b'Miami Vice            ',
#  b'The BFG',
#  b'The Revenant',
#  b'Turbo',
#  b'Rango',
#  b'Penguins of Madagascar',
#  b'The Bourne Ultimatum',
#  b'Kung Fu Panda',
#  b'Ant-Man',
#  b'The Hunger Games: Catching Fire',
#  b'The Twilight Saga: Breaking Dawn - Part 2',
#  b'Home',
#  b'War of the Worlds',
#  b'Bad Boys II',
#  b'Puss in Boots',
#  b'Salt',
#  b'Noah',
#  b'The Adventures of Tintin',
#  b'Harry Potter and the Prisoner of Azkaban',
#  b'Australia',
#  b'After Earth',
#  b'Dinosaur',
#  b'Harry Potter and the Deathly Hallows: Part II',
#  b'Night at the Museum: Secret of the Tomb',
#  b'Megamind',
#  b"Harry Potter and the Sorcerer's Stone",
#  b'R.I.P.D.',
#  b'Godzilla Resurgence',
#  b'Pirates of the Caribbean: The Curse of the Black Pearl',
#  b'Harry Potter and the Deathly Hallows: Part I',
#  b'The Hunger Games: Mockingjay - Part 1',
#  b'The Da Vinci Code',
#  b'Rio 2',
#  b'X-Men 2',
#  b'Fast Five',
#  b'Sherlock Holmes: A Game of Shadows',
#  b'Clash of the Titans',
#  b'Total Recall',
#  b'The 13th Warrior',
#  b'The Bourne Legacy',
#  b'Batman & Robin',
#  b'How the Grinch Stole Christmas',
#  b'The Day After Tomorrow',
#  b'Mission: Impossible II',
#  b'The Perfect Storm',
#  b'Fantastic 4: Rise of the Silver Surfer',
#  b'Life of Pi',
#  b'Ghost Rider',
#  b'Jason Bourne',
#  b"Charlie's Angels: Full Throttle",
#  b'Prometheus',
#  b'Stuart Little 2',
#  b'Elysium',
#  b'The Chronicles of Riddick',
#  b'RoboCop',
#  b'Speed Racer',
#  b'How Do You Know',
#  b'Knight and Day',
#  b'Oblivion',
#  b'Star Wars: Episode III - Revenge of the Sith',
#  b'Star Wars: Episode II - Attack of the Clones',
#  b'Monsters, Inc.',
#  b'The Wolverine',
#  b'Star Wars: Episode I - The Phantom Menace',
#  b'The Croods',
#  b'Asterix at the Olympic Games',
#  b'Windtalkers',
#  b"The Huntsman: Winter's War",
#  b'Teenage Mutant Ninja Turtles',
#  b'Gravity',
#  b"Dante's Peak",
#  b'Teenage Mutant Ninja Turtles: Out of the Shadows',
#  b'Fantastic Four',
#  b'Night at the Museum',
#  b'San Andreas',
#  b'Tomorrow Never Dies',
#  b'The Patriot',
#  b"Ocean's Twelve",
#  b'Mr. & Mrs. Smith',
#  b'Insurgent',
#  b'The Aviator',
#  b"Gulliver's Travels",
#  b'The Green Hornet',
#  b'The A-Team            ',
#  b'300: Rise of an Empire',
#  b'The Smurfs',
#  b'Home on the Range',
#  b'Allegiant',
#  b'Real Steel',
#  b'The Smurfs 2',
#  b'Speed 2: Cruise Control',
#  b"Ender's Game",
#  b'Live Free or Die Hard',
#  b'The Lord of the Rings: The Fellowship of the Ring',
#  b'Around the World in 80 Days',
#  b'Ali',
#  b'The Cat in the Hat',
#  b'I, Robot',
#  b'Kingdom of Heaven',
#  b'Stuart Little',
#  b'The Princess and the Frog',
#  b'The Martian',
#  b'10,000 B.C.            ',
#  b'The Island',
#  b'Town & Country',
#  b'Gone in Sixty Seconds',
#  b'Gladiator',
#  b'Minority Report',
#  b'Harry Potter and the Chamber of Secrets',
#  b'Casino Royale',
#  b'Planet of the Apes',
#  b'Terminator 2: Judgment Day',
#  b'Public Enemies',
#  b'American Gangster',
#  b'True Lies',
#  b'The Taking of Pelham 1 2 3',
#  b'Little Fockers',
#  b'The Other Guys',
#  b'Eraser',
#  b'Django Unchained',
#  b'The Hunchback of Notre Dame',
#  b"The Emperor's New Groove",
#  b'The Expendables 2',
#  b'National Treasure',
#  b'Eragon',
#  b'Where the Wild Things Are',
#  b'Pan',
#  b'Epic',
#  b'The Tourist',
#  b'End of Days',
#  b'Blood Diamond',
#  b'The Wolf of Wall Street',
#  b'Batman Forever',
#  b'Starship Troopers',
#  b'Cloud Atlas',
#  b"Legend of the Guardians: The Owls of Ga'Hoole",
#  b'Catwoman',
#  b'Hercules',
#  b'Treasure Planet',
#  b'Land of the Lost',
#  b'The Expendables 3',
#  b'Point Break',
#  b'Son of the Mask',
#  b'In the Heart of the Sea',
#  b'The Adventures of Pluto Nash',
#  b'Green Zone',
#  b'The Peanuts Movie',
#  b'The Spanish Prisoner',
#  b'The Mummy Returns',
#  b'Gangs of New York',
#  b'The Flowers of War',
#  b"Surf's Up",
#  b'The Stepford Wives',
#  b'Black Hawk Down',
#  b'The Campaign',
#  b'The Fifth Element',
#  b'Sex and the City 2',
#  b'The Road to El Dorado',
#  b'Ice Age: Continental Drift',
#  b'Cinderella',
#  b'The Lovely Bones',
#  b'Finding Nemo',
#  b'The Lord of the Rings: The Return of the King',
#  b'The Lord of the Rings: The Two Towers',
#  b'Seventh Son',
#  b'Lara Croft: Tomb Raider',
#  b'Transcendence',
#  b'Jurassic Park III',
#  b'Rise of the Planet of the Apes',
#  b'The Spiderwick Chronicles',
#  b'A Good Day to Die Hard',
#  b'The Alamo',
#  b'The Incredibles',
#  b'Cutthroat Island',
#  b'Percy Jackson & the Olympians: The Lightning Thief',
#  b'Men in Black',
#  b'Toy Story 2',
#  b'Unstoppable',
#  b'Rush Hour 2',
#  b'What Lies Beneath',
#  b'Cloudy with a Chance of Meatballs',
#  b'Ice Age: Dawn of the Dinosaurs',
#  b'The Secret Life of Walter Mitty',
#  b"Charlie's Angels",
#  b'The Departed',
#  b'Mulan',
#  b'Tropic Thunder',
#  b'The Girl with the Dragon Tattoo',
#  b'Die Hard with a Vengeance',
#  b'Sherlock Holmes',
#  b'Ben-Hur',
#  b'Atlantis: The Lost Empire',
#  b'Alvin and the Chipmunks: The Road Chip',
#  b'Valkyrie',
#  b"You Don't Mess with the Zohan",
#  b'Pixels',
#  b'A.I. Artificial Intelligence',
#  b'The Haunted Mansion',
#  b'Contact',
#  b'Hollow Man',
#  b'The Interpreter',
#  b'Percy Jackson: Sea of Monsters',
#  b'Lara Croft Tomb Raider: The Cradle of Life',
#  b'Now You See Me 2',
#  b'The Saint',
#  b'Spy Game',
#  b'Mission to Mars',
#  b'Rio',
#  b'Bicentennial Man',
#  b'Volcano',
#  b"The Devil's Own",
#  b'K-19: The Widowmaker',
#  b'Fantastic Four',
#  b'Conan the Barbarian',
#  b'Cinderella Man',
#  b'The Nutcracker in 3D',
#  b'Seabiscuit',
#  b'Twister',
#  b'The Fast and the Furious',
#  b'Cast Away',
#  b'Happy Feet',
#  b'The Bourne Supremacy',
#  b'Air Force One',
#  b"Ocean's Eleven",
#  b'The Three Musketeers',
#  b'Hotel Transylvania',
#  b'Enchanted',
#  b'Hannibal            ',
#  b'Safe House',
#  b'102 Dalmatians',
#  b'Tower Heist',
#  b'The Holiday',
#  b'Enemy of the State',
#  b"It's Complicated",
#  b"Ocean's Thirteen",
#  b'Open Season',
#  b'Divergent',
#  b'Enemy at the Gates',
#  b'The Rundown',
#  b'Last Action Hero',
#  b'Memoirs of a Geisha',
#  b'The Fast and the Furious: Tokyo Drift',
#  b'Arthur Christmas',
#  b'Meet Joe Black',
#  b'Collateral Damage',
#  b'All That Jazz',
#  b'Mirror Mirror',
#  b'Scott Pilgrim vs. the World',
#  b'The Core',
#  b'Nutty Professor II: The Klumps',
#  b'Scooby-Doo',
#  b'Dredd',
#  b'Click',
#  b'Creepshow',
#  b'Cats & Dogs: The Revenge of Kitty Galore',
#  b'Jumper',
#  b'Hellboy II: The Golden Army',
#  b'Zodiac',
#  b'The 6th Day',
#  b'Bruce Almighty',
#  b'The Expendables',
#  b'Mission: Impossible',
#  b'The Hunger Games',
#  b'The Hangover Part II',
#  b'Batman Returns',
#  b'Over the Hedge',
#  b'Lilo & Stitch',
#  b"Charlotte's Web",
#  b'Deep Impact',
#  b'RED 2',
#  b'The Longest Yard',
#  b'Alvin and the Chipmunks: Chipwrecked',
#  b'Grown Ups 2',
#  b'Get Smart',
#  b"Something's Gotta Give",
#  b'Shutter Island',
#  b'Four Christmases',
#  b'Robots',
#  b'Face/Off',
#  b'Bedtime Stories',
#  b'Road to Perdition',
#  b'Just Go with It',
#  b'Daredevil            ',
#  b'Con Air',
#  b'Eagle Eye',
#  b'Cold Mountain',
#  b'The Book of Eli',
#  b'Flubber',
#  b'The Haunting',
#  b'Space Jam',
#  b'The Pink Panther',
#  b'The Day the Earth Stood Still',
#  b'Conspiracy Theory',
#  b'Fury',
#  b'Six Days Seven Nights',
#  b'Yogi Bear',
#  b'Spirit: Stallion of the Cimarron',
#  b'Zookeeper',
#  b'Lost in Space',
#  b'The Manchurian Candidate',
#  b'Dj Vu',
#  b'Hotel Transylvania 2',
#  b'Bewitched            ',
#  b'Fantasia 2000',
#  b'The Time Machine',
#  b'Mighty Joe Young',
#  b'Swordfish',
#  b'The Legend of Zorro',
#  b'What Dreams May Come',
#  b'Little Nicky',
#  b'The Brothers Grimm',
#  b'Mars Attacks!',
#  b'Evolution',
#  b'The Edge',
#  b'Surrogates',
#  b'Thirteen Days',
#  b'Daylight',
#  b'Walking with Dinosaurs 3D',
#  b'Battlefield Earth',
#  b'Looney Tunes: Back in Action',
#  b'Nine',
#  b'Timeline',
#  b'The Postman',
#  b'Babe: Pig in the City',
#  b'The Last Witch Hunter',
#  b'Red Planet',
#  b'Arthur and the Invisibles',
#  b'Oceans',
#  b'A Sound of Thunder',
#  b'Pompeii',
#  b'Top Cat Begins',
#  b'A Beautiful Mind',
#  b'The Lion King',
#  b'Journey 2: The Mysterious Island',
#  b'Cloudy with a Chance of Meatballs 2',
#  b'Red Dragon',
#  b'Hidalgo',
#  b'Jack and Jill',
#  b'2 Fast 2 Furious',
#  b'The Little Prince',
#  b'The Invasion',
#  b'The Adventures of Rocky & Bullwinkle',
#  b'The Secret Life of Pets',
#  b'The League of Extraordinary Gentlemen',
#  b'Despicable Me 2',
#  b'Independence Day',
#  b'The Lost World: Jurassic Park',
#  b'Madagascar',
#  b'Children of Men',
#  b'X-Men',
#  b'Wanted',
#  b'The Rock',
#  b'Ice Age: The Meltdown',
#  b'50 First Dates',
#  b'Hairspray',
#  b'Exorcist: The Beginning',
#  b'Inspector Gadget',
#  b'Now You See Me',
#  b'Grown Ups',
#  b'The Terminal',
#  b'Constantine            ',
#  b'Hotel for Dogs',
#  b'Vertical Limit',
#  b"Charlie Wilson's War",
#  b'Shark Tale',
#  b'Dreamgirls',
#  b'Life            ',
#  b'Be Cool',
#  b'Munich',
#  b'Tears of the Sun',
#  b'Killers',
#  b'The Man from U.N.C.L.E.',
#  b'Spanglish',
#  b'Monster House',
#  b'Bandits',
#  b'First Knight',
#  b'Anna and the King',
#  b'Immortals',
#  b'Hostage',
#  b'Titan A.E.',
#  b'Hollywood Homicide',
#  b'Soldier',
#  b'Carriers',
#  b'Monkeybone',
#  b'Flight of the Phoenix',
#  b'Unbreakable',
#  b'Minions',
#  b'Sucker Punch',
#  b'Snake Eyes',
#  b'Sphere',
#  b'The Angry Birds Movie',
#  b"Fool's Gold",
#  b'Funny People',
#  b'The Kingdom',
#  b'Talladega Nights: The Ballad of Ricky Bobby',
#  b'Dr. Dolittle 2',
#  b'Braveheart',
#  b'Jarhead',
#  b'The Simpsons Movie',
#  b'The Majestic',
#  b'Driven',
#  b'Two Brothers',
#  b'The Village',
#  b'Doctor Dolittle',
#  b'Signs',
#  b'Shrek 2',
#  b'Cars',
#  b'Runaway Bride',
#  b'xXx',
#  b'The SpongeBob Movie: Sponge Out of Water',
#  b'Ransom',
#  b'Inglourious Basterds',
#  b'Hook',
#  b'Hercules',
#  b'Die Hard 2',
#  b'S.W.A.T.',
#  b'Sleepy Hollow            ',
#  b'Vanilla Sky',
#  b'Lady in the Water',
#  b'AVP: Alien vs. Predator',
#  b'Alvin and the Chipmunks: The Squeakquel',
#  b'We Were Soldiers',
#  b'Olympus Has Fallen',
#  b'Star Trek: Insurrection',
#  b'Battle Los Angeles',
#  b'Big Fish',
#  b'Wolf',
#  b'War Horse',
#  b'The Monuments Men',
#  b'The Abyss',
#  b'Wall Street: Money Never Sleeps',
#  b'Dracula Untold',
#  b'The Siege',
#  b'Stardust',
#  b'Seven Years in Tibet',
#  b'The Dilemma',
#  b'Bad Company',
#  b'Doom',
#  b'I Spy',
#  b'Underworld: Awakening',
#  b'Rock of Ages',
#  b"Hart's War",
#  b'Killer Elite',
#  b'Rollerball',
#  b'Ballistic: Ecks vs. Sever',
#  b'Hard Rain',
#  b'Osmosis Jones',
#  b"Legends of Oz: Dorothy's Return",
#  b'Blackhat',
#  b'Sky Captain and the World of Tomorrow',
#  b'Basic Instinct 2',
#  b'Escape Plan',
#  b'The Legend of Hercules',
#  b'The Sum of All Fears',
#  b'The Twilight Saga: Eclipse',
#  b'The Score',
#  b'Despicable Me',
#  b'Money Train',
#  b'Ted 2',
#  b'Agora',
#  b'Mystery Men',
#  b'Hall Pass',
#  b'The Insider',
#  b'The Finest Hours',
#  b'Body of Lies',
#  b'Dinner for Schmucks',
#  b'Abraham Lincoln: Vampire Hunter',
#  b'Entrapment',
#  b'Last Man Standing            ',
#  b'The X Files',
#  b'The Last Legion',
#  b'Saving Private Ryan',
#  b'Need for Speed',
#  b'What Women Want',
#  b'Ice Age',
#  b'Dreamcatcher',
#  b'Lincoln',
#  b'The Matrix',
#  b'Apollo 13',
#  b'Total Recall',
#  b'The Santa Clause 2',
#  b'Les Misrables',
#  b"You've Got Mail",
#  b'Step Brothers',
#  b'The Mask of Zorro',
#  b'Due Date',
#  b'Unbroken',
#  b'Space Cowboys',
#  b'Cliffhanger',
#  b'Broken Arrow',
#  b'The Kid',
#  b'World Trade Center',
#  b'Mona Lisa Smile',
#  b'The Dictator',
#  b'Eyes Wide Shut',
#  b'Annie',
#  b'Focus',
#  b'This Means War',
#  b'Blade: Trinity',
#  b'Red Dawn',
#  b'Primary Colors',
#  b'Resident Evil: Retribution',
#  b'Death Race',
#  b'The Long Kiss Goodnight',
#  b'Proof of Life',
#  b'Zathura: A Space Adventure',
#  b'Fight Club',
#  b'We Are Marshall',
#  b'The Missing            ',
#  b'Hudson Hawk',
#  b'Lucky Numbers',
#  b'I, Frankenstein',
#  b'Oliver Twist',
#  b'Elektra',
#  b'Sin City: A Dame to Kill For',
#  b'Random Hearts',
#  b'Everest',
#  b'Perfume: The Story of a Murderer',
#  b'Austin Powers in Goldmember',
#  b'Astro Boy',
#  b'Jurassic Park',
#  b'Wyatt Earp',
#  b'Clear and Present Danger',
#  b'Dragon Blade',
#  b'Littleman',
#  b'U-571',
#  b'The American President',
#  b'The Love Guru',
#  b'3000 Miles to Graceland',
#  b'The Hateful Eight',
#  b'Blades of Glory',
#  b'Hop',
#  b'300',
#  b'Meet the Fockers',
#  b'Marley & Me',
#  b'The Green Mile',
#  b'Wild Hogs',
#  b'Chicken Little',
#  b'Gone Girl',
#  b'The Bourne Identity',
#  b'GoldenEye',
#  b"The General's Daughter",
#  b'The Truman Show',
#  b'The Prince of Egypt',
#  b'Daddy Day Care',
#  b'2 Guns',
#  b'Cats & Dogs',
#  b'The Italian Job',
#  b'Two Weeks Notice',
#  b'Antz',
#  b'Couples Retreat',
#  b'Days of Thunder',
#  b'Cheaper by the Dozen 2',
#  b'The Scorch Trials',
#  b'Eat Pray Love',
#  b'The Family Man',
#  b'RED',
#  b'Any Given Sunday',
#  b'The Horse Whisperer',
#  b'Collateral',
#  b'The Scorpion King',
#  b'Ladder 49',
#  b'Jack Reacher',
#  b'Deep Blue Sea',
#  b'This Is It',
#  b'Contagion',
#  b'Kangaroo Jack',
#  b'Coraline',
#  b'The Happening',
#  b'Man on Fire',
#  b'The Shaggy Dog',
#  b'Starsky & Hutch',
#  b'Jingle All the Way',
#  b'Hellboy',
#  b'A Civil Action',
#  b'ParaNorman',
#  b'The Jackal',
#  b'Paycheck',
#  b'Up Close & Personal',
#  b'The Tale of Despereaux',
#  b'Rules of Engagement            ',
#  b'The Tuxedo',
#  b'Under Siege 2: Dark Territory',
#  b'Jack Ryan: Shadow Recruit',
#  b'Joy',
#  b'London Has Fallen',
#  b'Alien: Resurrection',
#  b'Shooter',
#  b'The Boxtrolls',
#  b'Practical Magic',
#  b'The Lego Movie',
#  b'Miss Congeniality 2: Armed and Fabulous',
#  b'Reign of Fire',
#  b'Gangster Squad',
#  b'Year One',
#  b'Invictus',
#  b'State of Play',
#  b'Duplicity',
#  b'My Favorite Martian',
#  b'The Sentinel',
#  b'Planet 51',
#  b'Star Trek: Nemesis',
#  b'Intolerable Cruelty',
#  b'Trouble with the Curve',
#  b'Edge of Darkness',
#  b'The Relic',
#  b'Analyze That',
#  b'Righteous Kill',
#  b'Mercury Rising',
#  b'The Soloist',
#  b'The Legend of Bagger Vance',
#  b'Almost Famous',
#  b'Garfield 2',
#  b'xXx: State of the Union',
#  b'Priest',
#  b'Sinbad: Legend of the Seven Seas',
#  b'Event Horizon',
#  b'The Avengers',
#  b'Dragonfly',
#  b'The Black Dahlia',
#  b'Flyboys',
#  b'The Last Castle',
#  b'Supernova',
#  b"Winter's Tale",
#  b'The Mortal Instruments: City of Bones',
#  b'Meet Dave',
#  b'Dark Water',
#  b'Edtv',
#  b'Inkheart',
#  b'The Spirit',
#  b'Mortdecai',
#  b'In the Name of the King: A Dungeon Siege Tale',
#  b'Beyond Borders',
#  b'Xi you ji zhi: Sun Wukong san da Baigu Jing',
#  b'The Great Raid',
#  b'Deadpool',
#  b'Holy Man',
#  b'American Sniper',
#  b'Goosebumps',
#  b'Sabrina, the Teenage Witch            ',
#  b'Just Like Heaven',
#  b'The Flintstones in Viva Rock Vegas',
#  b'Rambo III',
#  b'Leatherheads',
#  b'The Ridiculous 6',
#  b'Did You Hear About the Morgans?',
#  b'The Internship',
#  b'Resident Evil: Afterlife',
#  b'Red Tails',
#  b'Sex and the City            ',
#  b"The Devil's Advocate",
#  b"That's My Boy",
#  b'DragonHeart',
#  b'After the Sunset',
#  b'Ghost Rider: Spirit of Vengeance',
#  b"Captain Corelli's Mandolin",
#  b'Anger Management            ',
#  b'The Pacifier',
#  b'Walking Tall',
#  b'Forrest Gump',
#  b'Alvin and the Chipmunks',
#  b'Meet the Parents',
#  b'Pocahontas',
#  b'Superman',
#  b'The Nutty Professor',
#  b'Hitch',
#  b'George of the Jungle',
#  b'American Wedding',
#  b'Captain Phillips',
#  b'Date Night',
#  b'Casper',
#  b'The Equalizer',
#  b'Maid in Manhattan',
#  b'Crimson Tide',
#  b'The Pursuit of Happyness',
#  b'Flightplan',
#  b'Disclosure',
#  b'City of Angels',
#  b'Kill Bill: Vol. 1',
#  b'Bowfinger',
#  b'Stargate SG-1            ',
#  b'Kill Bill: Vol. 2',
#  b'Tango & Cash',
#  b'Death Becomes Her',
#  b'Shanghai Noon',
#  b'Executive Decision',
#  b"Mr. Popper's Penguins",
#  b'The Forbidden Kingdom',
#  b'Free Birds',
#  b'Alien 3',
#  b'Evita',
#  b'Ronin',
#  b'The Ghost and the Darkness',
#  b'Paddington',
#  b'The Watch',
#  b'The Hunted',
#  b'Instinct',
#  b'Stuck on You',
#  b'Semi-Pro',
#  b'The Pirates! Band of Misfits',
#  b'Changeling',
#  b'Chain Reaction',
#  b'The Fan',
#  b'The Phantom of the Opera',
#  b'Elizabeth: The Golden Age',
#  b'on Flux',
#  b'Gods and Generals',
#  b'Turbulence',
#  b'Imagine That',
#  b'Muppets Most Wanted',
#  b'Thunderbirds',
#  b'Burlesque',
#  b'A Very Long Engagement',
#  b'Lolita',
#  b'Eye See You',
#  b'Blade II',
#  b'Seven Pounds',
#  b'Bullet to the Head',
#  b'The Godfather: Part III',
#  b'Elizabethtown',
#  b'You, Me and Dupree',
#  b'Superman II',
#  b'Gigli',
#  b"All the King's Men",
#  b'Shaft',
#  b'Anastasia',
#  b'Moulin Rouge!',
#  b'Domestic Disturbance',
#  b'Black Mass',
#  b'Flags of Our Fathers',
#  b'Law Abiding Citizen',
#  b'Grindhouse',
#  b'Beloved',
#  b'Lucky You',
#  b'Catch Me If You Can',
#  b'Zero Dark Thirty',
#  b'The Break-Up',
#  b'Mamma Mia!',
#  b"Valentine's Day",
#  b'The Dukes of Hazzard',
#  b'The Thin Red Line',
#  b'The Change-Up',
#  b'Man on the Moon',
#  b'Casino',
#  b'From Paris with Love',
#  b'Bulletproof Monk',
#  b'Me, Myself & Irene',
#  b'Barnyard',
#  b'Deck the Halls',
#  b'The Twilight Saga: New Moon',
#  b'Shrek',
#  b'The Adjustment Bureau',
#  b'Robin Hood: Prince of Thieves',
#  b'Jerry Maguire',
#  b'Ted',
#  b'As Good as It Gets',
#  b'Patch Adams',
#  b'Anchorman 2: The Legend Continues',
#  b'Mr. Deeds',
#  b'Super 8',
#  b'Erin Brockovich',
#  b'How to Lose a Guy in 10 Days',
#  b'22 Jump Street',
#  b'Interview with the Vampire: The Vampire Chronicles',
#  b'Yes Man',
#  b'Central Intelligence',
#  b'Stepmom',
#  b"Daddy's Home",
#  b'Into the Woods',
#  b'Inside Man',
#  b'Payback',
#  b'Congo',
#  b'We Bought a Zoo',
#  b'Knowing',
#  b'Failure to Launch',
#  b'The Ring Two',
#  b'Crazy, Stupid, Love.',
#  b'Garfield',
#  b'Christmas with the Kranks',
#  b'Moneyball',
#  b'Outbreak',
#  b'Non-Stop',
#  b'Race to Witch Mountain',
#  b'V for Vendetta',
#  b'Shanghai Knights',
#  b'Unforgotten            ',
#  b'Curious George',
#  b'Herbie Fully Loaded',
#  b"Don't Say a Word",
#  b'Hansel & Gretel: Witch Hunters',
#  b'Unfaithful',
#  b'I Am Number Four',
#  b'Syriana',
#  b'13 Hours',
#  b'The Book of Life',
#  b'Firewall',
#  b'Absolute Power',
#  b'G.I. Jane',
#  b'The Game',
#  b'Silent Hill',
#  b'The Replacements',
#  b'American Reunion',
#  b'The Negotiator',
#  b'Into the Storm',
#  b'Beverly Hills Cop III',
#  b'Gremlins 2: The New Batch',
#  b'The Judge',
#  b'The Peacemaker',
#  b'Resident Evil: Apocalypse',
#  b'Bridget Jones: The Edge of Reason',
#  b'Out of Time',
#  b'On Deadly Ground',
#  b'The Adventures of Sharkboy and Lavagirl 3-D',
#  b'The Beach',
#  b'Raising Helen',
#  b'Ninja Assassin',
#  b'For Love of the Game',
#  b'A Touch of Frost            ',
#  b'Striptease',
#  b'Marmaduke',
#  b'Hereafter',
#  b'Murder by Numbers',
#  b'Assassins',
#  ...]

# %%
# a weakness though is that it removes enye
print(data[data.movie_title.str.contains("ñ")]["movie_title"])
print("The following removed the enye:")
print(data[data.movie_title.str.contains("ñ")]["movie_title"].apply(
    lambda x: x.encode().decode('unicode_escape').encode('ascii','ignore')).tolist())
# Out:
# 4796    Quinceañera
# Name: movie_title, dtype: object
# The following removed the enye:
# [b'Quinceaera']

# %%
data["movie_title"] = data["movie_title"].apply(
    lambda x: x.encode().decode('unicode_escape').encode('ascii','ignore'))

# %% [markdown]
# # Data Cleaning

# %% [markdown]
# Replace values with 0. Of course, imputation could be done here, but other libraries are need for it.
#
# We are adding a new reference to the original data. Only the new cells are allocated memory.
#
# The unchanged cells are referenced to the original.

# %%
cleaned_data = data.fillna(0)

# %% [markdown]
# ## Data Summaries

# %%
cleaned_data.describe()
# Out:
#        num_critic_for_reviews     duration  director_facebook_likes  \
# count             5044.000000  5044.000000              5044.000000
# mean               138.776764   106.861023               672.218279
# std                121.795659    25.869713              2785.611681
# min                  0.000000     0.000000                 0.000000
# 25%                 48.000000    93.000000                 6.000000
# 50%                108.500000   103.000000                45.000000
# 75%                194.000000   118.000000               189.000000
# max                813.000000   511.000000             23000.000000
#
#        actor_3_facebook_likes  actor_1_facebook_likes         gross  \
# count             5044.000000             5044.000000  5.044000e+03
# mean               641.940722             6549.642546  3.996434e+07
# std               1661.668020            15011.110715  6.483380e+07
# min                  0.000000                0.000000  0.000000e+00
# 25%                130.000000              611.000000  3.031302e+05
# 50%                367.000000              985.500000  1.522984e+07
# 75%                635.000000            11000.000000  5.133721e+07
# max              23000.000000           640000.000000  7.605058e+08
#
#        num_voted_users  cast_total_facebook_likes  facenumber_in_poster  \
# count     5.044000e+03                5044.000000           5044.000000
# mean      8.365157e+04                9697.140960              1.367367
# std       1.384765e+05               18162.511577              2.012073
# min       0.000000e+00                   0.000000              0.000000
# 25%       8.581750e+03                1411.000000              0.000000
# 50%       3.435750e+04                3090.000000              1.000000
# 75%       9.627100e+04               13754.250000              2.000000
# max       1.689764e+06              656730.000000             43.000000
#
#        num_user_for_reviews        budget   title_year  \
# count           5044.000000  5.044000e+03  5044.000000
# mean             271.581086  3.586720e+07  1959.596749
# std              377.585698  1.961367e+08   290.153085
# min                0.000000  0.000000e+00     0.000000
# 25%               64.000000  3.000000e+06  1998.000000
# 50%              155.000000  1.500000e+07  2005.000000
# 75%              324.000000  4.000000e+07  2011.000000
# max             5060.000000  1.221550e+10  2016.000000
#
#        actor_2_facebook_likes   imdb_score  aspect_ratio  movie_facebook_likes
# count             5044.000000  5044.000000   5044.000000           5044.000000
# mean              1647.169905     6.440860      2.075135           7524.472443
# std               4037.759216     1.128655      1.447240          19318.820075
# min                  0.000000     0.000000      0.000000              0.000000
# 25%                278.000000     5.800000      1.850000              0.000000
# 50%                595.000000     6.600000      1.850000            165.500000
# 75%                918.000000     7.200000      2.350000           3000.000000
# max             137000.000000     9.500000     16.000000         349000.000000

# %% [markdown]
# ## Data Correlations

# %%
cleaned_data.corr()
# Out:
#                            num_critic_for_reviews  duration  \
# num_critic_for_reviews                   1.000000  0.269957
# duration                                 0.269957  1.000000
# director_facebook_likes                  0.184942  0.161057
# actor_3_facebook_likes                   0.273130  0.123878
# actor_1_facebook_likes                   0.193322  0.089381
# gross                                    0.524884  0.254773
# num_voted_users                          0.626649  0.313770
# cast_total_facebook_likes                0.266189  0.123360
# facenumber_in_poster                    -0.033755  0.004985
# num_user_for_reviews                     0.612024  0.329757
# budget                                   0.127874  0.074785
# title_year                               0.153370  0.261492
# actor_2_facebook_likes                   0.284396  0.131934
# imdb_score                               0.299959  0.259765
# aspect_ratio                             0.055258 -0.016001
# movie_facebook_likes                     0.682596  0.195677
#
#                            director_facebook_likes  actor_3_facebook_likes  \
# num_critic_for_reviews                    0.184942                0.273130
# duration                                  0.161057                0.123878
# director_facebook_likes                   1.000000                0.121308
# actor_3_facebook_likes                    0.121308                1.000000
# actor_1_facebook_likes                    0.092385                0.250455
# gross                                     0.149975                0.321765
# num_voted_users                           0.298072                0.287906
# cast_total_facebook_likes                 0.121131                0.474367
# facenumber_in_poster                     -0.041191                0.100510
# num_user_for_reviews                      0.223910                0.231251
# budget                                    0.024609                0.051278
# title_year                                0.032851                0.032404
# actor_2_facebook_likes                    0.121085                0.559993
# imdb_score                                0.162214                0.052168
# aspect_ratio                              0.006091                0.021094
# movie_facebook_likes                      0.162117                0.279254
#
#                            actor_1_facebook_likes     gross  num_voted_users  \
# num_critic_for_reviews                   0.193322  0.524884         0.626649
# duration                                 0.089381  0.254773         0.313770
# director_facebook_likes                  0.092385  0.149975         0.298072
# actor_3_facebook_likes                   0.250455  0.321765         0.287906
# actor_1_facebook_likes                   1.000000  0.167355         0.193137
# gross                                    0.167355  1.000000         0.651554
# num_voted_users                          0.193137  0.651554         1.000000
# cast_total_facebook_likes                0.951672  0.259799         0.265958
# facenumber_in_poster                     0.072998 -0.023865        -0.026623
# num_user_for_reviews                     0.146831  0.582966         0.798766
# budget                                   0.027301  0.123523         0.087497
# title_year                               0.054483  0.093693         0.058642
# actor_2_facebook_likes                   0.390789  0.284105         0.271243
# imdb_score                               0.076080  0.176566         0.410305
# aspect_ratio                             0.001651  0.026066         0.045424
# movie_facebook_likes                     0.135558  0.392661         0.537943
#
#                            cast_total_facebook_likes  facenumber_in_poster  \
# num_critic_for_reviews                      0.266189             -0.033755
# duration                                    0.123360              0.004985
# director_facebook_likes                     0.121131             -0.041191
# actor_3_facebook_likes                      0.474367              0.100510
# actor_1_facebook_likes                      0.951672              0.072998
# gross                                       0.259799             -0.023865
# num_voted_users                             0.265958             -0.026623
# cast_total_facebook_likes                   1.000000              0.091973
# facenumber_in_poster                        0.091973              1.000000
# num_user_for_reviews                        0.208067             -0.068176
# budget                                      0.041856             -0.018937
# title_year                                  0.059912             -0.018798
# actor_2_facebook_likes                      0.628616              0.072320
# imdb_score                                  0.086112             -0.061238
# aspect_ratio                                0.010541              0.002017
# movie_facebook_likes                        0.209818              0.007873
#
#                            num_user_for_reviews    budget  title_year  \
# num_critic_for_reviews                 0.612024  0.127874    0.153370
# duration                               0.329757  0.074785    0.261492
# director_facebook_likes                0.223910  0.024609    0.032851
# actor_3_facebook_likes                 0.231251  0.051278    0.032404
# actor_1_facebook_likes                 0.146831  0.027301    0.054483
# gross                                  0.582966  0.123523    0.093693
# num_voted_users                        0.798766  0.087497    0.058642
# cast_total_facebook_likes              0.208067  0.041856    0.059912
# facenumber_in_poster                  -0.068176 -0.018937   -0.018798
# num_user_for_reviews                   1.000000  0.093058    0.072690
# budget                                 0.093058  1.000000    0.028274
# title_year                             0.072690  0.028274    1.000000
# actor_2_facebook_likes                 0.220675  0.048909    0.047642
# imdb_score                             0.289641  0.025891   -0.155797
# aspect_ratio                           0.045000  0.007470   -0.367360
# movie_facebook_likes                   0.401228  0.066176    0.033245
#
#                            actor_2_facebook_likes  imdb_score  aspect_ratio  \
# num_critic_for_reviews                   0.284396    0.299959      0.055258
# duration                                 0.131934    0.259765     -0.016001
# director_facebook_likes                  0.121085    0.162214      0.006091
# actor_3_facebook_likes                   0.559993    0.052168      0.021094
# actor_1_facebook_likes                   0.390789    0.076080      0.001651
# gross                                    0.284105    0.176566      0.026066
# num_voted_users                          0.271243    0.410305      0.045424
# cast_total_facebook_likes                0.628616    0.086112      0.010541
# facenumber_in_poster                     0.072320   -0.061238      0.002017
# num_user_for_reviews                     0.220675    0.289641      0.045000
# budget                                   0.048909    0.025891      0.007470
# title_year                               0.047642   -0.155797     -0.367360
# actor_2_facebook_likes                   1.000000    0.083593      0.020407
# imdb_score                               0.083593    1.000000      0.095499
# aspect_ratio                             0.020407    0.095499      1.000000
# movie_facebook_likes                     0.243722    0.246687      0.060339
#
#                            movie_facebook_likes
# num_critic_for_reviews                 0.682596
# duration                               0.195677
# director_facebook_likes                0.162117
# actor_3_facebook_likes                 0.279254
# actor_1_facebook_likes                 0.135558
# gross                                  0.392661
# num_voted_users                        0.537943
# cast_total_facebook_likes              0.209818
# facenumber_in_poster                   0.007873
# num_user_for_reviews                   0.401228
# budget                                 0.066176
# title_year                             0.033245
# actor_2_facebook_likes                 0.243722
# imdb_score                             0.246687
# aspect_ratio                           0.060339
# movie_facebook_likes                   1.000000

# %% [markdown]
# ## Outliers : Clipping to the 99th percentile
#
# This is just one of the many rules-of-thumb used in practice. It doesn't always work, especially if one has too many outliers.

# %%
cleaned_data.duration.quantile(0.99)
# Out:
# 189.0

# %%
cleaned_data['duration'] = np.clip(cleaned_data['duration'], 0, 189)
cleaned_data.describe()
# Out:
#        num_critic_for_reviews     duration  director_facebook_likes  \
# count             5044.000000  5044.000000              5044.000000
# mean               138.776764   106.411975               672.218279
# std                121.795659    23.327743              2785.611681
# min                  0.000000     0.000000                 0.000000
# 25%                 48.000000    93.000000                 6.000000
# 50%                108.500000   103.000000                45.000000
# 75%                194.000000   118.000000               189.000000
# max                813.000000   189.000000             23000.000000
#
#        actor_3_facebook_likes  actor_1_facebook_likes         gross  \
# count             5044.000000             5044.000000  5.044000e+03
# mean               641.940722             6549.642546  3.996434e+07
# std               1661.668020            15011.110715  6.483380e+07
# min                  0.000000                0.000000  0.000000e+00
# 25%                130.000000              611.000000  3.031302e+05
# 50%                367.000000              985.500000  1.522984e+07
# 75%                635.000000            11000.000000  5.133721e+07
# max              23000.000000           640000.000000  7.605058e+08
#
#        num_voted_users  cast_total_facebook_likes  facenumber_in_poster  \
# count     5.044000e+03                5044.000000           5044.000000
# mean      8.365157e+04                9697.140960              1.367367
# std       1.384765e+05               18162.511577              2.012073
# min       0.000000e+00                   0.000000              0.000000
# 25%       8.581750e+03                1411.000000              0.000000
# 50%       3.435750e+04                3090.000000              1.000000
# 75%       9.627100e+04               13754.250000              2.000000
# max       1.689764e+06              656730.000000             43.000000
#
#        num_user_for_reviews        budget   title_year  \
# count           5044.000000  5.044000e+03  5044.000000
# mean             271.581086  3.586720e+07  1959.596749
# std              377.585698  1.961367e+08   290.153085
# min                0.000000  0.000000e+00     0.000000
# 25%               64.000000  3.000000e+06  1998.000000
# 50%              155.000000  1.500000e+07  2005.000000
# 75%              324.000000  4.000000e+07  2011.000000
# max             5060.000000  1.221550e+10  2016.000000
#
#        actor_2_facebook_likes   imdb_score  aspect_ratio  movie_facebook_likes
# count             5044.000000  5044.000000   5044.000000           5044.000000
# mean              1647.169905     6.440860      2.075135           7524.472443
# std               4037.759216     1.128655      1.447240          19318.820075
# min                  0.000000     0.000000      0.000000              0.000000
# 25%                278.000000     5.800000      1.850000              0.000000
# 50%                595.000000     6.600000      1.850000            165.500000
# 75%                918.000000     7.200000      2.350000           3000.000000
# max             137000.000000     9.500000     16.000000         349000.000000

# %% [markdown]
# ## Output to CSV File

# %%
cleaned_data.to_csv('data/movie_metadata_cleaned.csv')

# %%
cleaned_data.head(2)
# Out:
#                                    movie_title  color   director_name  \
# 0                                    b'Avatar'  Color   James Cameron
# 1  b"Pirates of the Caribbean: At World's End"  Color  Gore Verbinski
#
#    num_critic_for_reviews  duration  director_facebook_likes  \
# 0                   723.0     178.0                      0.0
# 1                   302.0     169.0                    563.0
#
#    actor_3_facebook_likes      actor_2_name  actor_1_facebook_likes  \
# 0                   855.0  Joel David Moore                  1000.0
# 1                  1000.0     Orlando Bloom                 40000.0
#
#          gross  ... num_user_for_reviews language  country  content_rating  \
# 0  760505847.0  ...               3054.0  English      USA           PG-13
# 1  309404152.0  ...               1238.0  English      USA           PG-13
#
#         budget  title_year actor_2_facebook_likes imdb_score  aspect_ratio  \
# 0  237000000.0      2009.0                  936.0        7.9          1.78
# 1  300000000.0      2007.0                 5000.0        7.1          2.35
#
#   movie_facebook_likes
# 0              33000.0
# 1                  0.0
#
# [2 rows x 28 columns]

# %% [markdown]
# # Aggregations
#
# In this example, the group by statement does two things:
#
# 1) groups together the dataframe by title_year
#
# 2) the size() function has the title_year as the index

# %%
cleaned_data["title_year"] = cleaned_data["title_year"].astype(np.int64)
movies_per_year = cleaned_data.groupby("title_year").size()
movies_per_year[-5:]
# Out:
# title_year
# 2012    221
# 2013    237
# 2014    253
# 2015    226
# 2016    106
# dtype: int64

# %%
like_per_year = cleaned_data.groupby("title_year")["movie_facebook_likes"].mean()
like_per_year[-5:]
# Out:
# title_year
# 2012    24259.004525
# 2013    25115.805907
# 2014    19850.422925
# 2015    19775.920354
# 2016    17610.669811
# Name: movie_facebook_likes, dtype: float64

# %% [markdown]
# ## Standardization
#
# Standardize  using the following formula then save it to a new column.
#
# $$Z={X-\operatorname {E} [X] \over \sigma (X)}$$
#
# In the following, standardize the movie_facebook_likes.

# %%
mean_fb_likes = data['movie_facebook_likes'].mean()

cleaned_data["st_movie_fb_likes"] = (data["movie_facebook_likes"] - mean_fb_likes) / cleaned_data["movie_facebook_likes"].std()
cleaned_data
# Out:
#                                             movie_title  color  \
# 0                                             b'Avatar'  Color
# 1           b"Pirates of the Caribbean: At World's End"  Color
# 2                                            b'Spectre'  Color
# 3                              b'The Dark Knight Rises'  Color
# 4     b'Star Wars: Episode VII - The Force Awakens  ...      0
# ...                                                 ...    ...
# 5039                       b'The Following            '  Color
# 5040                            b'A Plague So Pleasant'  Color
# 5041                                b'Shanghai Calling'  Color
# 5042                               b'My Date with Drew'  Color
# 5043                             b'Starting Over Again'      0
#
#           director_name  num_critic_for_reviews  duration  \
# 0         James Cameron                   723.0     178.0
# 1        Gore Verbinski                   302.0     169.0
# 2            Sam Mendes                   602.0     148.0
# 3     Christopher Nolan                   813.0     164.0
# 4           Doug Walker                     0.0       0.0
# ...                 ...                     ...       ...
# 5039                  0                    43.0      43.0
# 5040   Benjamin Roberds                    13.0      76.0
# 5041        Daniel Hsia                    14.0     100.0
# 5042           Jon Gunn                    43.0      90.0
# 5043     Olivia Lamasan                     0.0       0.0
#
#       director_facebook_likes  actor_3_facebook_likes      actor_2_name  \
# 0                         0.0                   855.0  Joel David Moore
# 1                       563.0                  1000.0     Orlando Bloom
# 2                         0.0                   161.0      Rory Kinnear
# 3                     22000.0                 23000.0    Christian Bale
# 4                       131.0                     0.0        Rob Walker
# ...                       ...                     ...               ...
# 5039                      0.0                   319.0     Valorie Curry
# 5040                      0.0                     0.0     Maxwell Moody
# 5041                      0.0                   489.0     Daniel Henney
# 5042                     16.0                    16.0  Brian Herzlinger
# 5043                      0.0                     0.0      Toni Gonzaga
#
#       actor_1_facebook_likes        gross  ...      country content_rating  \
# 0                     1000.0  760505847.0  ...          USA          PG-13
# 1                    40000.0  309404152.0  ...          USA          PG-13
# 2                    11000.0  200074175.0  ...           UK          PG-13
# 3                    27000.0  448130642.0  ...          USA          PG-13
# 4                      131.0          0.0  ...            0              0
# ...                      ...          ...  ...          ...            ...
# 5039                   841.0          0.0  ...          USA          TV-14
# 5040                     0.0          0.0  ...          USA              0
# 5041                   946.0      10443.0  ...          USA          PG-13
# 5042                    86.0      85222.0  ...          USA             PG
# 5043                     0.0          0.0  ...  Philippines             PG
#
#            budget  title_year actor_2_facebook_likes  imdb_score aspect_ratio  \
# 0     237000000.0        2009                  936.0         7.9         1.78
# 1     300000000.0        2007                 5000.0         7.1         2.35
# 2     245000000.0        2015                  393.0         6.8         2.35
# 3     250000000.0        2012                23000.0         8.5         2.35
# 4             0.0           0                   12.0         7.1         0.00
# ...           ...         ...                    ...         ...          ...
# 5039          0.0           0                  593.0         7.5        16.00
# 5040       1400.0        2013                    0.0         6.3         0.00
# 5041          0.0        2012                  719.0         6.3         2.35
# 5042       1100.0        2004                   23.0         6.6         1.85
# 5043          0.0        2014                    0.0         0.0         0.00
#
#      movie_facebook_likes  avg_rating st_movie_fb_likes
# 0                 33000.0    16503.95          1.318612
# 1                     0.0        3.55         -0.389566
# 2                 85000.0    42503.40          4.010288
# 3                164000.0    82004.25          8.099565
# 4                     0.0        3.55         -0.389566
# ...                   ...         ...               ...
# 5039              32000.0    16003.75          1.266849
# 5040                 16.0       11.15         -0.388738
# 5041                660.0      333.15         -0.355403
# 5042                456.0      231.30         -0.365963
# 5043                  0.0        0.00               NaN
#
# [5044 rows x 30 columns]

# %% [markdown]
# # Adding New columns
#
# Take the average of the IMDB Score and the (standardized) movie facebook likes for each movie, and store it to a new column.

# %%
cleaned_data['avg_rating'] = cleaned_data[['imdb_score', 'st_movie_fb_likes']].mean(axis=1)

# %%
cleaned_data
# Out:
#                                             movie_title  color  \
# 0                                             b'Avatar'  Color
# 1           b"Pirates of the Caribbean: At World's End"  Color
# 2                                            b'Spectre'  Color
# 3                              b'The Dark Knight Rises'  Color
# 4     b'Star Wars: Episode VII - The Force Awakens  ...      0
# ...                                                 ...    ...
# 5039                       b'The Following            '  Color
# 5040                            b'A Plague So Pleasant'  Color
# 5041                                b'Shanghai Calling'  Color
# 5042                               b'My Date with Drew'  Color
# 5043                             b'Starting Over Again'      0
#
#           director_name  num_critic_for_reviews  duration  \
# 0         James Cameron                   723.0     178.0
# 1        Gore Verbinski                   302.0     169.0
# 2            Sam Mendes                   602.0     148.0
# 3     Christopher Nolan                   813.0     164.0
# 4           Doug Walker                     0.0       0.0
# ...                 ...                     ...       ...
# 5039                  0                    43.0      43.0
# 5040   Benjamin Roberds                    13.0      76.0
# 5041        Daniel Hsia                    14.0     100.0
# 5042           Jon Gunn                    43.0      90.0
# 5043     Olivia Lamasan                     0.0       0.0
#
#       director_facebook_likes  actor_3_facebook_likes      actor_2_name  \
# 0                         0.0                   855.0  Joel David Moore
# 1                       563.0                  1000.0     Orlando Bloom
# 2                         0.0                   161.0      Rory Kinnear
# 3                     22000.0                 23000.0    Christian Bale
# 4                       131.0                     0.0        Rob Walker
# ...                       ...                     ...               ...
# 5039                      0.0                   319.0     Valorie Curry
# 5040                      0.0                     0.0     Maxwell Moody
# 5041                      0.0                   489.0     Daniel Henney
# 5042                     16.0                    16.0  Brian Herzlinger
# 5043                      0.0                     0.0      Toni Gonzaga
#
#       actor_1_facebook_likes        gross  ...      country content_rating  \
# 0                     1000.0  760505847.0  ...          USA          PG-13
# 1                    40000.0  309404152.0  ...          USA          PG-13
# 2                    11000.0  200074175.0  ...           UK          PG-13
# 3                    27000.0  448130642.0  ...          USA          PG-13
# 4                      131.0          0.0  ...            0              0
# ...                      ...          ...  ...          ...            ...
# 5039                   841.0          0.0  ...          USA          TV-14
# 5040                     0.0          0.0  ...          USA              0
# 5041                   946.0      10443.0  ...          USA          PG-13
# 5042                    86.0      85222.0  ...          USA             PG
# 5043                     0.0          0.0  ...  Philippines             PG
#
#            budget  title_year actor_2_facebook_likes  imdb_score aspect_ratio  \
# 0     237000000.0        2009                  936.0         7.9         1.78
# 1     300000000.0        2007                 5000.0         7.1         2.35
# 2     245000000.0        2015                  393.0         6.8         2.35
# 3     250000000.0        2012                23000.0         8.5         2.35
# 4             0.0           0                   12.0         7.1         0.00
# ...           ...         ...                    ...         ...          ...
# 5039          0.0           0                  593.0         7.5        16.00
# 5040       1400.0        2013                    0.0         6.3         0.00
# 5041          0.0        2012                  719.0         6.3         2.35
# 5042       1100.0        2004                   23.0         6.6         1.85
# 5043          0.0        2014                    0.0         0.0         0.00
#
#      movie_facebook_likes  avg_rating st_movie_fb_likes
# 0                 33000.0    4.609306          1.318612
# 1                     0.0    3.355217         -0.389566
# 2                 85000.0    5.405144          4.010288
# 3                164000.0    8.299782          8.099565
# 4                     0.0    3.355217         -0.389566
# ...                   ...         ...               ...
# 5039              32000.0    4.383425          1.266849
# 5040                 16.0    2.955631         -0.388738
# 5041                660.0    2.972299         -0.355403
# 5042                456.0    3.117019         -0.365963
# 5043                  0.0    0.000000               NaN
#
# [5044 rows x 30 columns]

# %% [markdown]
# # Data Normalization
#
# $$
# x_{scaled} = \frac{x-x_{min}}{x_{max}-x_{min}}
# $$
#
# Normalize duration and store it to a new column, nm_duration.

# %%
max = cleaned_data['duration'].max()
min = cleaned_data['duration'].min()
cleaned_data['nm_duration'] = (cleaned_data['duration'] - min) / (max-min)
cleaned_data
# Out:
#                                             movie_title  color  \
# 0                                             b'Avatar'  Color
# 1           b"Pirates of the Caribbean: At World's End"  Color
# 2                                            b'Spectre'  Color
# 3                              b'The Dark Knight Rises'  Color
# 4     b'Star Wars: Episode VII - The Force Awakens  ...      0
# ...                                                 ...    ...
# 5039                       b'The Following            '  Color
# 5040                            b'A Plague So Pleasant'  Color
# 5041                                b'Shanghai Calling'  Color
# 5042                               b'My Date with Drew'  Color
# 5043                             b'Starting Over Again'      0
#
#           director_name  num_critic_for_reviews  duration  \
# 0         James Cameron                   723.0     178.0
# 1        Gore Verbinski                   302.0     169.0
# 2            Sam Mendes                   602.0     148.0
# 3     Christopher Nolan                   813.0     164.0
# 4           Doug Walker                     0.0       0.0
# ...                 ...                     ...       ...
# 5039                  0                    43.0      43.0
# 5040   Benjamin Roberds                    13.0      76.0
# 5041        Daniel Hsia                    14.0     100.0
# 5042           Jon Gunn                    43.0      90.0
# 5043     Olivia Lamasan                     0.0       0.0
#
#       director_facebook_likes  actor_3_facebook_likes      actor_2_name  \
# 0                         0.0                   855.0  Joel David Moore
# 1                       563.0                  1000.0     Orlando Bloom
# 2                         0.0                   161.0      Rory Kinnear
# 3                     22000.0                 23000.0    Christian Bale
# 4                       131.0                     0.0        Rob Walker
# ...                       ...                     ...               ...
# 5039                      0.0                   319.0     Valorie Curry
# 5040                      0.0                     0.0     Maxwell Moody
# 5041                      0.0                   489.0     Daniel Henney
# 5042                     16.0                    16.0  Brian Herzlinger
# 5043                      0.0                     0.0      Toni Gonzaga
#
#       actor_1_facebook_likes        gross  ... content_rating       budget  \
# 0                     1000.0  760505847.0  ...          PG-13  237000000.0
# 1                    40000.0  309404152.0  ...          PG-13  300000000.0
# 2                    11000.0  200074175.0  ...          PG-13  245000000.0
# 3                    27000.0  448130642.0  ...          PG-13  250000000.0
# 4                      131.0          0.0  ...              0          0.0
# ...                      ...          ...  ...            ...          ...
# 5039                   841.0          0.0  ...          TV-14          0.0
# 5040                     0.0          0.0  ...              0       1400.0
# 5041                   946.0      10443.0  ...          PG-13          0.0
# 5042                    86.0      85222.0  ...             PG       1100.0
# 5043                     0.0          0.0  ...             PG          0.0
#
#       title_year  actor_2_facebook_likes imdb_score  aspect_ratio  \
# 0           2009                   936.0        7.9          1.78
# 1           2007                  5000.0        7.1          2.35
# 2           2015                   393.0        6.8          2.35
# 3           2012                 23000.0        8.5          2.35
# 4              0                    12.0        7.1          0.00
# ...          ...                     ...        ...           ...
# 5039           0                   593.0        7.5         16.00
# 5040        2013                     0.0        6.3          0.00
# 5041        2012                   719.0        6.3          2.35
# 5042        2004                    23.0        6.6          1.85
# 5043        2014                     0.0        0.0          0.00
#
#      movie_facebook_likes avg_rating  st_movie_fb_likes nm_duration
# 0                 33000.0   4.609306           1.318612    0.941799
# 1                     0.0   3.355217          -0.389566    0.894180
# 2                 85000.0   5.405144           4.010288    0.783069
# 3                164000.0   8.299782           8.099565    0.867725
# 4                     0.0   3.355217          -0.389566    0.000000
# ...                   ...        ...                ...         ...
# 5039              32000.0   4.383425           1.266849    0.227513
# 5040                 16.0   2.955631          -0.388738    0.402116
# 5041                660.0   2.972299          -0.355403    0.529101
# 5042                456.0   3.117019          -0.365963    0.476190
# 5043                  0.0   0.000000                NaN    0.000000
#
# [5044 rows x 31 columns]
